# %%
import pandas as pd

# %%
fi="tabula-qcuxk3y7c1ezwo5yylnn.csv"
df = pd.read_csv(fi)

# %%
df.head()
# Out:
#         Team  # Pos.   FIFA Popular Name  Birth Date  Shirt Name  \
# 0  Argentina  1   GK       GUZMAN Nahuel  10.02.1986      GUZMÁN
# 1  Argentina  2   DF     MERCADO Gabriel  18.03.1987     MERCADO
# 2  Argentina  3   DF  TAGLIAFICO Nicolas  31.08.1992  TAGLIAFICO
# 3  Argentina  4   DF    ANSALDI Cristian  20.09.1986     ANSALDI
# 4  Argentina  5   MF        BIGLIA Lucas  30.01.1986      BIGLIA
#
#                 Club Height Weight
# 0  Tigres UANL (MEX)    192     90
# 1   Sevilla FC (ESP)    181     81
# 2     AFC Ajax (NED)    169     65
# 3    Torino FC (ITA)    181     73
# 4     AC Milan (ITA)    175     73

# %%
df.describe()
# Out:
#         Team    # Pos.  FIFA Popular Name  Birth Date  Shirt Name  Club  \
# count    767  767  767                767         767         767   767
# unique    33   24    5                736         680         729   311
# top     Team   18   DF  FIFA Popular Name  Birth Date  Shirt Name  Club
# freq      31   32  248                 31          31          31    31
#
#        Height Weight
# count     767    767
# unique     38     42
# top       185     78
# freq       53     53

# %%
df[20:30]
# Out:
#          Team   #  Pos.   FIFA Popular Name  Birth Date  Shirt Name  \
# 20  Argentina  21    FW        DYBALA Paulo  15.11.1993      DYBALA
# 21  Argentina  22    MF      PAVON Cristian  21.01.1996       PAVÓN
# 22  Argentina  23    GK  CABALLERO Wilfredo  28.09.1981   CABALLERO
# 23       Team   #  Pos.   FIFA Popular Name  Birth Date  Shirt Name
# 24  Australia   1    GK         RYAN Mathew  08.04.1992        RYAN
# 25  Australia   2    DF       DEGENEK Milos  28.04.1994     DEGENEK
# 26  Australia   3    DF      MEREDITH James  05.04.1988    MEREDITH
# 27  Australia   4    FW          CAHILL Tim  06.12.1979      CAHILL
# 28  Australia   5    DF       MILLIGAN Mark  04.08.1985    MILLIGAN
# 29  Australia   6    DF      JURMAN Matthew  08.12.1989      JURMAN
#
#                                 Club  Height  Weight
# 20                 Juventus FC (ITA)     177      73
# 21             CA Boca Juniors (ARG)     169      65
# 22                  Chelsea FC (ENG)     186      80
# 23                              Club  Height  Weight
# 24   Brighton & Hove Albion FC (ENG)     184      82
# 25          Yokohama F-Marinos (JPN)     187      85
# 26                 Millwall FC (ENG)     179      71
# 27                 Millwall FC (ENG)     180      76
# 28                  Al Ahli SC (KSA)     178      78
# 29  Suwon Samsung Bluewings FC (KOR)     190      83

# %%
df.dtypes
# Out:
# Team                 object
# #                    object
# Pos.                 object
# FIFA Popular Name    object
# Birth Date           object
# Shirt Name           object
# Club                 object
# Height               object
# Weight               object
# dtype: object

# %%
# remove header row (is there because frame is conctenation of each team's table)
df = df[df.Team != 'Team']
df[10:30]
# Out:
#          Team   # Pos.   FIFA Popular Name  Birth Date  Shirt Name  \
# 10  Argentina  11   MF      DI MARIA Angel  14.02.1988    DI MARÍA
# 11  Argentina  12   GK       ARMANI Franco  16.10.1986      ARMANI
# 12  Argentina  13   MF    MEZA Maximiliano  15.12.1992        MEZA
# 13  Argentina  14   DF   MASCHERANO Javier  08.06.1984  MASCHERANO
# 14  Argentina  15   MF      LANZINI Manuel  15.02.1993     LANZINI
# 15  Argentina  16   DF         ROJO Marcos  20.03.1990        ROJO
# 16  Argentina  17   DF    OTAMENDI Nicolas  12.02.1988    OTAMENDI
# 17  Argentina  18   DF      SALVIO Eduardo  13.07.1990      SALVIO
# 18  Argentina  19   FW       AGUERO Sergio  02.06.1988      AGÜERO
# 19  Argentina  20   MF    LO CELSO Giovani  09.04.1996    LO CELSO
# 20  Argentina  21   FW        DYBALA Paulo  15.11.1993      DYBALA
# 21  Argentina  22   MF      PAVON Cristian  21.01.1996       PAVÓN
# 22  Argentina  23   GK  CABALLERO Wilfredo  28.09.1981   CABALLERO
# 24  Australia   1   GK         RYAN Mathew  08.04.1992        RYAN
# 25  Australia   2   DF       DEGENEK Milos  28.04.1994     DEGENEK
# 26  Australia   3   DF      MEREDITH James  05.04.1988    MEREDITH
# 27  Australia   4   FW          CAHILL Tim  06.12.1979      CAHILL
# 28  Australia   5   DF       MILLIGAN Mark  04.08.1985    MILLIGAN
# 29  Australia   6   DF      JURMAN Matthew  08.12.1989      JURMAN
# 30  Australia   7   FW       LECKIE Mathew  04.02.1991      LECKIE
#
#                                 Club Height Weight
# 10      Paris Saint-Germain FC (FRA)    178     75
# 11              CA River Plate (ARG)    189     85
# 12            CA Independiente (ARG)    180     76
# 13      Hebei China Fortune FC (CHN)    174     73
# 14          West Ham United FC (ENG)    167     66
# 15        Manchester United FC (ENG)    189     82
# 16          Manchester City FC (ENG)    181     81
# 17                  SL Benfica (POR)    167     69
# 18          Manchester City FC (ENG)    172     74
# 19      Paris Saint-Germain FC (FRA)    177     75
# 20                 Juventus FC (ITA)    177     73
# 21             CA Boca Juniors (ARG)    169     65
# 22                  Chelsea FC (ENG)    186     80
# 24   Brighton & Hove Albion FC (ENG)    184     82
# 25          Yokohama F-Marinos (JPN)    187     85
# 26                 Millwall FC (ENG)    179     71
# 27                 Millwall FC (ENG)    180     76
# 28                  Al Ahli SC (KSA)    178     78
# 29  Suwon Samsung Bluewings FC (KOR)    190     83
# 30                  Hertha BSC (GER)    181     84

# %%
df.describe()
# Out:
#            Team    # Pos. FIFA Popular Name  Birth Date Shirt Name  \
# count       736  736  736               736         736        736
# unique       32   23    4               735         679        728
# top     Croatia   18   DF    SANCHEZ Carlos  05.03.1993  RODRIGUEZ
# freq         23   32  248                 2           3          3
#
#                             Club Height Weight
# count                        736    736    736
# unique                       310     37     41
# top     Manchester City FC (ENG)    185     78
# freq                          16     53     53

# %%
# the tallest player :
df['Height'].max()
# Out:
# '201'

# %%
# make object-> numeric so can run aggregations on top of it
df.apply(pd.to_numeric, errors='ignore')
# Out:
#           Team   # Pos.       FIFA Popular Name  Birth Date        Shirt Name  \
# 0    Argentina   1   GK           GUZMAN Nahuel  10.02.1986            GUZMÁN
# 1    Argentina   2   DF         MERCADO Gabriel  18.03.1987           MERCADO
# 2    Argentina   3   DF      TAGLIAFICO Nicolas  31.08.1992        TAGLIAFICO
# 3    Argentina   4   DF        ANSALDI Cristian  20.09.1986           ANSALDI
# 4    Argentina   5   MF            BIGLIA Lucas  30.01.1986            BIGLIA
# 5    Argentina   6   DF          FAZIO Federico  17.03.1987             FAZIO
# 6    Argentina   7   MF             BANEGA Ever  29.06.1988            BANEGA
# 7    Argentina   8   DF            ACUNA Marcos  28.10.1991             ACUÑA
# 8    Argentina   9   FW         HIGUAIN Gonzalo  10.12.1987           HIGUAÍN
# 9    Argentina  10   FW            MESSI Lionel  24.06.1987             MESSI
# 10   Argentina  11   MF          DI MARIA Angel  14.02.1988          DI MARÍA
# 11   Argentina  12   GK           ARMANI Franco  16.10.1986            ARMANI
# 12   Argentina  13   MF        MEZA Maximiliano  15.12.1992              MEZA
# 13   Argentina  14   DF       MASCHERANO Javier  08.06.1984        MASCHERANO
# 14   Argentina  15   MF          LANZINI Manuel  15.02.1993           LANZINI
# 15   Argentina  16   DF             ROJO Marcos  20.03.1990              ROJO
# 16   Argentina  17   DF        OTAMENDI Nicolas  12.02.1988          OTAMENDI
# 17   Argentina  18   DF          SALVIO Eduardo  13.07.1990            SALVIO
# 18   Argentina  19   FW           AGUERO Sergio  02.06.1988            AGÜERO
# 19   Argentina  20   MF        LO CELSO Giovani  09.04.1996          LO CELSO
# 20   Argentina  21   FW            DYBALA Paulo  15.11.1993            DYBALA
# 21   Argentina  22   MF          PAVON Cristian  21.01.1996             PAVÓN
# 22   Argentina  23   GK      CABALLERO Wilfredo  28.09.1981         CABALLERO
# 24   Australia   1   GK             RYAN Mathew  08.04.1992              RYAN
# 25   Australia   2   DF           DEGENEK Milos  28.04.1994           DEGENEK
# 26   Australia   3   DF          MEREDITH James  05.04.1988          MEREDITH
# 27   Australia   4   FW              CAHILL Tim  06.12.1979            CAHILL
# 28   Australia   5   DF           MILLIGAN Mark  04.08.1985          MILLIGAN
# 29   Australia   6   DF          JURMAN Matthew  08.12.1989            JURMAN
# 30   Australia   7   FW           LECKIE Mathew  04.02.1991            LECKIE
# ..         ...  ..  ...                     ...         ...               ...
# 736    Tunisia  17   MF           SKHIRI Ellyes  10.05.1995      SKHIRI JORIS
# 737    Tunisia  18   FW           SRARFI Bassem  25.06.1997            SRARFI
# 738    Tunisia  19   FW           KHALIFA Saber  14.10.1986           KHALIFA
# 739    Tunisia  20   FW        CHAALELI Ghaylen  28.02.1994          CHAALELI
# 740    Tunisia  21   DF            NAGUEZ Hamdi  28.10.1992            NAGUEZ
# 741    Tunisia  22   GK            HASSEN Mouez  05.03.1995            HASSEN
# 742    Tunisia  23   FW              SLITI Naim  27.07.1992             SLITI
# 744    Uruguay   1   GK        MUSLERA Fernando  16.06.1986        F. MUSLERA
# 745    Uruguay   2   DF            GIMENEZ Jose  20.01.1995      J.M. GIMENEZ
# 746    Uruguay   3   DF             GODIN Diego  16.02.1986          D. GODIN
# 747    Uruguay   4   DF        VARELA Guillermo  24.03.1993         G. VARELA
# 748    Uruguay   5   MF          SANCHEZ Carlos  02.12.1984        C. SANCHEZ
# 749    Uruguay   6   MF       BENTANCUR Rodrigo  25.06.1997      R. BENTANCUR
# 750    Uruguay   7   MF      RODRIGUEZ Cristian  30.09.1985      C. RODRIGUEZ
# 751    Uruguay   8   MF          NANDEZ Nahitan  28.12.1995         N. NANDEZ
# 752    Uruguay   9   FW             SUAREZ Luis  24.01.1987         L. SUAREZ
# 753    Uruguay  10   FW  DE ARRASCAETA Giorgian  01.06.1994  G. DE ARRASCAETA
# 754    Uruguay  11   FW        STUANI Cristhian  12.10.1986         C. STUANI
# 755    Uruguay  12   GK          CAMPANA Martin  29.05.1989        M. CAMPAÑA
# 756    Uruguay  13   DF            SILVA Gaston  05.03.1994          G. SILVA
# 757    Uruguay  14   MF          TORREIRA Lucas  11.02.1996       L. TORREIRA
# 758    Uruguay  15   MF           VECINO Matias  24.08.1991         M. VECINO
# 759    Uruguay  16   DF     PEREIRA Maximiliano  08.06.1984        M. PEREIRA
# 760    Uruguay  17   MF            LAXALT Diego  07.02.1993         D. LAXALT
# 761    Uruguay  18   FW       GOMEZ Maximiliano  14.08.1996          M. GOMEZ
# 762    Uruguay  19   DF        COATES Sebastian  07.10.1990         S. COATES
# 763    Uruguay  20   FW  URRETAVISCAYA Jonathan  19.03.1990  J. URRETAVISCAYA
# 764    Uruguay  21   FW          CAVANI Edinson  14.02.1987         E. CAVANI
# 765    Uruguay  22   DF          CACERES Martin  07.04.1987        M. CACERES
# 766    Uruguay  23   GK            SILVA Martin  25.03.1983          M. SILVA
#
#                                  Club  Height  Weight
# 0                   Tigres UANL (MEX)     192      90
# 1                    Sevilla FC (ESP)     181      81
# 2                      AFC Ajax (NED)     169      65
# 3                     Torino FC (ITA)     181      73
# 4                      AC Milan (ITA)     175      73
# 5                       AS Roma (ITA)     199      85
# 6                    Sevilla FC (ESP)     175      73
# 7                   Sporting CP (POR)     172      77
# 8                   Juventus FC (ITA)     184      75
# 9                  FC Barcelona (ESP)     170      72
# 10       Paris Saint-Germain FC (FRA)     178      75
# 11               CA River Plate (ARG)     189      85
# 12             CA Independiente (ARG)     180      76
# 13       Hebei China Fortune FC (CHN)     174      73
# 14           West Ham United FC (ENG)     167      66
# 15         Manchester United FC (ENG)     189      82
# 16           Manchester City FC (ENG)     181      81
# 17                   SL Benfica (POR)     167      69
# 18           Manchester City FC (ENG)     172      74
# 19       Paris Saint-Germain FC (FRA)     177      75
# 20                  Juventus FC (ITA)     177      73
# 21              CA Boca Juniors (ARG)     169      65
# 22                   Chelsea FC (ENG)     186      80
# 24    Brighton & Hove Albion FC (ENG)     184      82
# 25           Yokohama F-Marinos (JPN)     187      85
# 26                  Millwall FC (ENG)     179      71
# 27                  Millwall FC (ENG)     180      76
# 28                   Al Ahli SC (KSA)     178      78
# 29   Suwon Samsung Bluewings FC (KOR)     190      83
# 30                   Hertha BSC (GER)     181      84
# ..                                ...     ...     ...
# 736             Montpellier HSC (FRA)     185      69
# 737                    OGC Nice (FRA)     176      71
# 738               Club Africain (TUN)     185      72
# 739                    ES Tunis (TUN)     179      70
# 740                     Zamalek (EGY)     186      75
# 741              LB Chateauroux (FRA)     186      70
# 742                   Dijon FCO (FRA)     173      65
# 744              Galatasaray SK (TUR)     190      74
# 745             Atletico Madrid (ESP)     185      77
# 746             Atletico Madrid (ESP)     185      73
# 747                  CA Penarol (URU)     173      70
# 748                CF Monterrey (MEX)     171      74
# 749                 Juventus FC (ITA)     187      73
# 750                  CA Penarol (URU)     178      79
# 751             CA Boca Juniors (ARG)     171      61
# 752                FC Barcelona (ESP)     182      85
# 753                 Cruzeiro EC (BRA)     172      64
# 754                   Girona FC (ESP)     186      78
# 755            CA Independiente (ARG)     184      79
# 756            CA Independiente (ARG)     185      74
# 757                UC Sampdoria (ITA)     168      61
# 758           FC Internazionale (ITA)     189      80
# 759                    FC Porto (POR)     173      73
# 760                   Genoa CFC (ITA)     178      66
# 761                  Celta Vigo (ESP)     186      85
# 762                 Sporting CP (POR)     196      89
# 763                CF Monterrey (MEX)     172      66
# 764      Paris Saint-Germain FC (FRA)     188      78
# 765                    SS Lazio (ITA)     178      75
# 766            CR Vasco da Gama (BRA)     187      82
#
# [736 rows x 9 columns]

# %%
df.dtypes
# Out:
# Team                 object
# #                    object
# Pos.                 object
# FIFA Popular Name    object
# Birth Date           object
# Shirt Name           object
# Club                 object
# Height               object
# Weight               object
# dtype: object

# %%
df['Height'] = df['Height'].astype('int64')

# %%
df = df.reset_index(drop=True)

# %%
df.head()
# Out:
#         Team  # Pos.   FIFA Popular Name  Birth Date  Shirt Name  \
# 0  Argentina  1   GK       GUZMAN Nahuel  10.02.1986      GUZMÁN
# 1  Argentina  2   DF     MERCADO Gabriel  18.03.1987     MERCADO
# 2  Argentina  3   DF  TAGLIAFICO Nicolas  31.08.1992  TAGLIAFICO
# 3  Argentina  4   DF    ANSALDI Cristian  20.09.1986     ANSALDI
# 4  Argentina  5   MF        BIGLIA Lucas  30.01.1986      BIGLIA
#
#                 Club  Height Weight
# 0  Tigres UANL (MEX)     192     90
# 1   Sevilla FC (ESP)     181     81
# 2     AFC Ajax (NED)     169     65
# 3    Torino FC (ITA)     181     73
# 4     AC Milan (ITA)     175     73

# %%
# find index of the tallest player
ind = df['Height'].idxmax()
ind
# Out:
# 149

# %%
pd.__version__
# Out:
# '0.22.0'

# %%
# and the tallest player is:
df.iloc[149]
# Out:
# Team                        Croatia
# #                                12
# Pos.                             GK
# FIFA Popular Name     KALINIC Lovre
# Birth Date               03.04.1990
# Shirt Name               L. KALINIĆ
# Club                 KAA Gent (BEL)
# Height                          201
# Weight                           96
# Name: 149, dtype: object

# %%
df[149:150]
# Out:
#         Team   # Pos. FIFA Popular Name  Birth Date  Shirt Name  \
# 149  Croatia  12   GK     KALINIC Lovre  03.04.1990  L. KALINIĆ
#
#                Club  Height Weight
# 149  KAA Gent (BEL)     201     96

# %%
df.dtypes
# Out:
# Team                 object
# #                    object
# Pos.                 object
# FIFA Popular Name    object
# Birth Date           object
# Shirt Name           object
# Club                 object
# Height                int64
# Weight               object
# dtype: object

# %%
# and the shortest player is ...
df.iloc[df['Height'].idxmin()]
# Out:
# Team                                   Panama
# #                                          19
# Pos.                                       MF
# FIFA Popular Name            QUINTERO Alberto
# Birth Date                         18.12.1987
# Shirt Name                           QUINTERO
# Club                 Universitario Lima (PER)
# Height                                    165
# Weight                                     62
# Name: 455, dtype: object

# %%
# average hight by team
df.groupby('Team', as_index=False)['Height'].mean().sort_values('Height')
# Out:
#               Team      Height
# 20            Peru  177.608696
# 24    Saudi Arabia  177.652174
# 0        Argentina  178.434783
# 14           Japan  178.782609
# 22        Portugal  179.739130
# 16          Mexico  179.782609
# 27           Spain  179.913043
# 5       Costa Rica  180.695652
# 3           Brazil  180.782609
# 4         Colombia  180.782609
# 1        Australia  180.869565
# 8            Egypt  181.000000
# 31         Uruguay  181.043478
# 15  Korea Republic  181.869565
# 19          Panama  182.173913
# 17         Morocco  182.695652
# 9          England  182.739130
# 29     Switzerland  182.913043
# 30         Tunisia  183.086957
# 21          Poland  183.173913
# 10          France  183.304348
# 25         Senegal  183.652174
# 23          Russia  184.391304
# 12         IR Iran  184.478261
# 18         Nigeria  184.521739
# 6          Croatia  185.260870
# 2          Belgium  185.347826
# 13         Iceland  185.521739
# 28          Sweden  185.739130
# 11         Germany  185.782609
# 7          Denmark  186.608696
# 26          Serbia  186.695652

# %%
# shortest teams are Peru, Saudi Arabia, Argentina
# tallest Serbia, Denmark, Germany

# %%
# same but add a column for median and the variance (standard deviation)
df.groupby('Team', as_index=False).agg({'Height':['mean','median','std']}).sort_values([("Height","mean")])
# Out:
#               Team      Height
#                           mean median       std
# 20            Peru  177.608696    178  5.860027
# 24    Saudi Arabia  177.652174    177  7.164361
# 0        Argentina  178.434783    177  8.478991
# 14           Japan  178.782609    179  5.616182
# 22        Portugal  179.739130    179  7.256454
# 16          Mexico  179.782609    180  6.908207
# 27           Spain  179.913043    179  6.894748
# 5       Costa Rica  180.695652    180  5.320926
# 3           Brazil  180.782609    182  7.354383
# 4         Colombia  180.782609    181  5.608083
# 1        Australia  180.869565    180  6.797756
# 8            Egypt  181.000000    181  7.229988
# 31         Uruguay  181.043478    184  7.642455
# 15  Korea Republic  181.869565    183  7.485163
# 19          Panama  182.173913    183  6.117428
# 17         Morocco  182.695652    183  6.108376
# 9          England  182.739130    183  7.312613
# 29     Switzerland  182.913043    184  5.367521
# 30         Tunisia  183.086957    185  5.290756
# 21          Poland  183.173913    184  6.575797
# 10          France  183.304348    183  7.600447
# 25         Senegal  183.652174    184  7.327462
# 23          Russia  184.391304    185  5.458431
# 12         IR Iran  184.478261    185  4.925532
# 18         Nigeria  184.521739    185  6.940458
# 6          Croatia  185.260870    186  6.173384
# 2          Belgium  185.347826    186  7.595505
# 13         Iceland  185.521739    186  5.623567
# 28          Sweden  185.739130    185  5.553192
# 11         Germany  185.782609    186  5.248000
# 7          Denmark  186.608696    187  7.371562
# 26          Serbia  186.695652    187  6.189689

# %%
import datetime

# %%
def func(x):
    return datetime.datetime.strptime(x, '%d.%m.%Y').date()

df['birth date corrected']=df['Birth Date'].apply(lambda x: func(x))

# %%
df.head()
# Out:
#         Team  # Pos.   FIFA Popular Name  Birth Date  Shirt Name  \
# 0  Argentina  1   GK       GUZMAN Nahuel  10.02.1986      GUZMÁN
# 1  Argentina  2   DF     MERCADO Gabriel  18.03.1987     MERCADO
# 2  Argentina  3   DF  TAGLIAFICO Nicolas  31.08.1992  TAGLIAFICO
# 3  Argentina  4   DF    ANSALDI Cristian  20.09.1986     ANSALDI
# 4  Argentina  5   MF        BIGLIA Lucas  30.01.1986      BIGLIA
#
#                 Club  Height Weight birth date corrected
# 0  Tigres UANL (MEX)     192     90           1986-02-10
# 1   Sevilla FC (ESP)     181     81           1987-03-18
# 2     AFC Ajax (NED)     169     65           1992-08-31
# 3    Torino FC (ITA)     181     73           1986-09-20
# 4     AC Milan (ITA)     175     73           1986-01-30

# %%
from datetime import date
def calculate_age(born):
    today = date.today()
    return today.year - born.year - ((today.month, today.day) < (born.month, born.day))

df['age']=df['birth date corrected'].apply(lambda x: calculate_age(x))

# %%
df.head()
# Out:
#         Team  # Pos.   FIFA Popular Name  Birth Date  Shirt Name  \
# 0  Argentina  1   GK       GUZMAN Nahuel  10.02.1986      GUZMÁN
# 1  Argentina  2   DF     MERCADO Gabriel  18.03.1987     MERCADO
# 2  Argentina  3   DF  TAGLIAFICO Nicolas  31.08.1992  TAGLIAFICO
# 3  Argentina  4   DF    ANSALDI Cristian  20.09.1986     ANSALDI
# 4  Argentina  5   MF        BIGLIA Lucas  30.01.1986      BIGLIA
#
#                 Club  Height Weight birth date corrected  age
# 0  Tigres UANL (MEX)     192     90           1986-02-10   32
# 1   Sevilla FC (ESP)     181     81           1987-03-18   31
# 2     AFC Ajax (NED)     169     65           1992-08-31   25
# 3    Torino FC (ITA)     181     73           1986-09-20   31
# 4     AC Milan (ITA)     175     73           1986-01-30   32

# %%
def calc_age_as_fraction(birth_date):
    days_in_year = 365.2425  
    return (date.today() - birth_date).days / days_in_year
df['age_fraction']=df['birth date corrected'].apply(lambda x: calc_age_as_fraction(x))

# %%
df.head()
# Out:
#         Team  # Pos.   FIFA Popular Name  Birth Date  Shirt Name  \
# 0  Argentina  1   GK       GUZMAN Nahuel  10.02.1986      GUZMÁN
# 1  Argentina  2   DF     MERCADO Gabriel  18.03.1987     MERCADO
# 2  Argentina  3   DF  TAGLIAFICO Nicolas  31.08.1992  TAGLIAFICO
# 3  Argentina  4   DF    ANSALDI Cristian  20.09.1986     ANSALDI
# 4  Argentina  5   MF        BIGLIA Lucas  30.01.1986      BIGLIA
#
#                 Club  Height Weight birth date corrected  age  age_fraction
# 0  Tigres UANL (MEX)     192     90           1986-02-10   32     32.397654
# 1   Sevilla FC (ESP)     181     81           1987-03-18   31     31.299753
# 2     AFC Ajax (NED)     169     65           1992-08-31   25     25.843104
# 3    Torino FC (ITA)     181     73           1986-09-20   31     31.789838
# 4     AC Milan (ITA)     175     73           1986-01-30   32     32.427771

# %%
# average age by team with median and variance (standard deviation)
df_age =df.groupby('Team', as_index=False).agg({'age_fraction':['mean','median','std']}).sort_values([("age_fraction","mean")])

# %%
df_age
# Out:
#               Team age_fraction
#                            mean     median       std
# 18         Nigeria    26.022378  25.722636  3.584070
# 10          France    26.087968  25.306474  3.865659
# 9          England    26.108324  25.552886  3.425027
# 30         Tunisia    26.584601  26.297597  3.152637
# 26          Serbia    26.819109  26.445444  4.659981
# 11         Germany    27.196821  27.992361  3.166333
# 7          Denmark    27.201582  26.836964  3.518264
# 29     Switzerland    27.240984  26.735662  3.646030
# 25         Senegal    27.241937  27.860942  3.452524
# 12         IR Iran    27.288957  26.209984  3.584288
# 17         Morocco    27.291695  28.356503  4.667825
# 20            Peru    27.498467  27.058735  3.559142
# 2          Belgium    27.643457  27.491324  3.159754
# 15  Korea Republic    27.843800  28.351027  2.795694
# 6          Croatia    27.961292  28.999911  3.492365
# 4         Colombia    28.122471  27.291457  3.348145
# 31         Uruguay    28.189252  28.296269  4.471642
# 1        Australia    28.192467  26.954694  4.330165
# 28          Sweden    28.294840  28.433164  2.908518
# 21          Poland    28.369121  28.876705  3.690127
# 22        Portugal    28.423998  27.108017  5.040025
# 27           Spain    28.546133  28.460543  3.612570
# 14           Japan    28.638031  28.131994  3.322459
# 13         Iceland    28.641245  28.821947  4.264290
# 3           Brazil    28.662315  29.065621  3.433450
# 24    Saudi Arabia    28.788259  28.619342  3.622853
# 23          Russia    28.896347  28.726120  4.264683
# 8            Egypt    29.039075  29.260012  5.093390
# 0        Argentina    29.275130  30.388030  3.665096
# 19          Panama    29.321437  29.676174  5.207314
# 16          Mexico    29.420834  29.150496  4.581896
# 5       Costa Rica    29.615226  29.602251  3.700252

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_age.unstack(['age_fraction']).head()
# Out:
# Team    18    Nigeria
#         10     France
#         9     England
#         30    Tunisia
#         26     Serbia
# dtype: object

# %%
df['Team'] = df['Team'].astype('|S')

# %%
ax = df_age['age_fraction']['mean'].plot(x=df_age['Team'],kind="bar",color=['blue'])
# ax.set_xticklabels(df_age['Team'], rotation=90)

# %%
# ax = df_age['age_fraction']['mean'].plot(x=df_age['Team'],kind="bar",color=['blue'])
# ax.set_xticklabels(df_age['Team'], rotation=90)
fig, ax = plt.subplots()
fig.set_size_inches(18.5, 10.5)
width=0.75
# ax.bar(list(df_age['Team']),sorted(list(df_age['age_fraction']['mean'].sort_values())), width , color='b', yerr=list(df_age['age_fraction']['std']))
ax = df_age['age_fraction']['mean'].plot(x=df_age['Team'],kind="bar",color=['blue'],yerr=df_age['age_fraction']['std'])

ax.set_xticklabels(list(df_age['Team']), rotation=90)
ax.set_title("National team age")
plt.show()

# %%
df_height =df.groupby('Team', as_index=False).agg({'Height':['mean','median','std']}).sort_values([("Height","mean")])
df_height
# Out:
#                  Team      Height
#                              mean median       std
# 20            b'Peru'  177.608696    178  5.860027
# 24    b'Saudi Arabia'  177.652174    177  7.164361
# 0        b'Argentina'  178.434783    177  8.478991
# 14           b'Japan'  178.782609    179  5.616182
# 22        b'Portugal'  179.739130    179  7.256454
# 16          b'Mexico'  179.782609    180  6.908207
# 27           b'Spain'  179.913043    179  6.894748
# 5       b'Costa Rica'  180.695652    180  5.320926
# 3           b'Brazil'  180.782609    182  7.354383
# 4         b'Colombia'  180.782609    181  5.608083
# 1        b'Australia'  180.869565    180  6.797756
# 8            b'Egypt'  181.000000    181  7.229988
# 31         b'Uruguay'  181.043478    184  7.642455
# 15  b'Korea Republic'  181.869565    183  7.485163
# 19          b'Panama'  182.173913    183  6.117428
# 17         b'Morocco'  182.695652    183  6.108376
# 9          b'England'  182.739130    183  7.312613
# 29     b'Switzerland'  182.913043    184  5.367521
# 30         b'Tunisia'  183.086957    185  5.290756
# 21          b'Poland'  183.173913    184  6.575797
# 10          b'France'  183.304348    183  7.600447
# 25         b'Senegal'  183.652174    184  7.327462
# 23          b'Russia'  184.391304    185  5.458431
# 12         b'IR Iran'  184.478261    185  4.925532
# 18         b'Nigeria'  184.521739    185  6.940458
# 6          b'Croatia'  185.260870    186  6.173384
# 2          b'Belgium'  185.347826    186  7.595505
# 13         b'Iceland'  185.521739    186  5.623567
# 28          b'Sweden'  185.739130    185  5.553192
# 11         b'Germany'  185.782609    186  5.248000
# 7          b'Denmark'  186.608696    187  7.371562
# 26          b'Serbia'  186.695652    187  6.189689

# %%
fig, ax = plt.subplots()
fig.set_size_inches(18.5, 10.5)
width=0.75
ax = df_height['Height']['mean'].plot(x=df_height['Team'],kind="bar",color=['blue'],yerr=df_height['Height']['std'])
ax.set_xticklabels(list(df_height['Team']), rotation=90)
ax.set_title("National team height")
plt.show()

# %%
#calc bmi - body mass index
# bmi = mass/height^2
ctn=0
def calc_bmi(x):
#     global ctn
    
#     ctn+=1
#     bmi=int(x['Weight'])/int(x['Height'])**2
#     print(ctn,bmi)
    mass = x['Weight']
    height = x['Height']
    bmi = int(mass) / int((height/100)**2)
#     print(ctn,mass,height,bmi)

    return bmi

df['BMI']=df.apply(lambda x: calc_bmi(x),axis=1)
# d.apply(lambda row: min([row['A'], row['B']])-row['C'], axis=1)

# %%
df
# Out:
#              Team   # Pos.       FIFA Popular Name  Birth Date  \
# 0    b'Argentina'   1   GK           GUZMAN Nahuel  10.02.1986
# 1    b'Argentina'   2   DF         MERCADO Gabriel  18.03.1987
# 2    b'Argentina'   3   DF      TAGLIAFICO Nicolas  31.08.1992
# 3    b'Argentina'   4   DF        ANSALDI Cristian  20.09.1986
# 4    b'Argentina'   5   MF            BIGLIA Lucas  30.01.1986
# 5    b'Argentina'   6   DF          FAZIO Federico  17.03.1987
# 6    b'Argentina'   7   MF             BANEGA Ever  29.06.1988
# 7    b'Argentina'   8   DF            ACUNA Marcos  28.10.1991
# 8    b'Argentina'   9   FW         HIGUAIN Gonzalo  10.12.1987
# 9    b'Argentina'  10   FW            MESSI Lionel  24.06.1987
# 10   b'Argentina'  11   MF          DI MARIA Angel  14.02.1988
# 11   b'Argentina'  12   GK           ARMANI Franco  16.10.1986
# 12   b'Argentina'  13   MF        MEZA Maximiliano  15.12.1992
# 13   b'Argentina'  14   DF       MASCHERANO Javier  08.06.1984
# 14   b'Argentina'  15   MF          LANZINI Manuel  15.02.1993
# 15   b'Argentina'  16   DF             ROJO Marcos  20.03.1990
# 16   b'Argentina'  17   DF        OTAMENDI Nicolas  12.02.1988
# 17   b'Argentina'  18   DF          SALVIO Eduardo  13.07.1990
# 18   b'Argentina'  19   FW           AGUERO Sergio  02.06.1988
# 19   b'Argentina'  20   MF        LO CELSO Giovani  09.04.1996
# 20   b'Argentina'  21   FW            DYBALA Paulo  15.11.1993
# 21   b'Argentina'  22   MF          PAVON Cristian  21.01.1996
# 22   b'Argentina'  23   GK      CABALLERO Wilfredo  28.09.1981
# 23   b'Australia'   1   GK             RYAN Mathew  08.04.1992
# 24   b'Australia'   2   DF           DEGENEK Milos  28.04.1994
# 25   b'Australia'   3   DF          MEREDITH James  05.04.1988
# 26   b'Australia'   4   FW              CAHILL Tim  06.12.1979
# 27   b'Australia'   5   DF           MILLIGAN Mark  04.08.1985
# 28   b'Australia'   6   DF          JURMAN Matthew  08.12.1989
# 29   b'Australia'   7   FW           LECKIE Mathew  04.02.1991
# ..            ...  ..  ...                     ...         ...
# 706    b'Tunisia'  17   MF           SKHIRI Ellyes  10.05.1995
# 707    b'Tunisia'  18   FW           SRARFI Bassem  25.06.1997
# 708    b'Tunisia'  19   FW           KHALIFA Saber  14.10.1986
# 709    b'Tunisia'  20   FW        CHAALELI Ghaylen  28.02.1994
# 710    b'Tunisia'  21   DF            NAGUEZ Hamdi  28.10.1992
# 711    b'Tunisia'  22   GK            HASSEN Mouez  05.03.1995
# 712    b'Tunisia'  23   FW              SLITI Naim  27.07.1992
# 713    b'Uruguay'   1   GK        MUSLERA Fernando  16.06.1986
# 714    b'Uruguay'   2   DF            GIMENEZ Jose  20.01.1995
# 715    b'Uruguay'   3   DF             GODIN Diego  16.02.1986
# 716    b'Uruguay'   4   DF        VARELA Guillermo  24.03.1993
# 717    b'Uruguay'   5   MF          SANCHEZ Carlos  02.12.1984
# 718    b'Uruguay'   6   MF       BENTANCUR Rodrigo  25.06.1997
# 719    b'Uruguay'   7   MF      RODRIGUEZ Cristian  30.09.1985
# 720    b'Uruguay'   8   MF          NANDEZ Nahitan  28.12.1995
# 721    b'Uruguay'   9   FW             SUAREZ Luis  24.01.1987
# 722    b'Uruguay'  10   FW  DE ARRASCAETA Giorgian  01.06.1994
# 723    b'Uruguay'  11   FW        STUANI Cristhian  12.10.1986
# 724    b'Uruguay'  12   GK          CAMPANA Martin  29.05.1989
# 725    b'Uruguay'  13   DF            SILVA Gaston  05.03.1994
# 726    b'Uruguay'  14   MF          TORREIRA Lucas  11.02.1996
# 727    b'Uruguay'  15   MF           VECINO Matias  24.08.1991
# 728    b'Uruguay'  16   DF     PEREIRA Maximiliano  08.06.1984
# 729    b'Uruguay'  17   MF            LAXALT Diego  07.02.1993
# 730    b'Uruguay'  18   FW       GOMEZ Maximiliano  14.08.1996
# 731    b'Uruguay'  19   DF        COATES Sebastian  07.10.1990
# 732    b'Uruguay'  20   FW  URRETAVISCAYA Jonathan  19.03.1990
# 733    b'Uruguay'  21   FW          CAVANI Edinson  14.02.1987
# 734    b'Uruguay'  22   DF          CACERES Martin  07.04.1987
# 735    b'Uruguay'  23   GK            SILVA Martin  25.03.1983
#
#            Shirt Name                              Club  Height Weight  \
# 0              GUZMÁN                 Tigres UANL (MEX)     192     90
# 1             MERCADO                  Sevilla FC (ESP)     181     81
# 2          TAGLIAFICO                    AFC Ajax (NED)     169     65
# 3             ANSALDI                   Torino FC (ITA)     181     73
# 4              BIGLIA                    AC Milan (ITA)     175     73
# 5               FAZIO                     AS Roma (ITA)     199     85
# 6              BANEGA                  Sevilla FC (ESP)     175     73
# 7               ACUÑA                 Sporting CP (POR)     172     77
# 8             HIGUAÍN                 Juventus FC (ITA)     184     75
# 9               MESSI                FC Barcelona (ESP)     170     72
# 10           DI MARÍA      Paris Saint-Germain FC (FRA)     178     75
# 11             ARMANI              CA River Plate (ARG)     189     85
# 12               MEZA            CA Independiente (ARG)     180     76
# 13         MASCHERANO      Hebei China Fortune FC (CHN)     174     73
# 14            LANZINI          West Ham United FC (ENG)     167     66
# 15               ROJO        Manchester United FC (ENG)     189     82
# 16           OTAMENDI          Manchester City FC (ENG)     181     81
# 17             SALVIO                  SL Benfica (POR)     167     69
# 18             AGÜERO          Manchester City FC (ENG)     172     74
# 19           LO CELSO      Paris Saint-Germain FC (FRA)     177     75
# 20             DYBALA                 Juventus FC (ITA)     177     73
# 21              PAVÓN             CA Boca Juniors (ARG)     169     65
# 22          CABALLERO                  Chelsea FC (ENG)     186     80
# 23               RYAN   Brighton & Hove Albion FC (ENG)     184     82
# 24            DEGENEK          Yokohama F-Marinos (JPN)     187     85
# 25           MEREDITH                 Millwall FC (ENG)     179     71
# 26             CAHILL                 Millwall FC (ENG)     180     76
# 27           MILLIGAN                  Al Ahli SC (KSA)     178     78
# 28             JURMAN  Suwon Samsung Bluewings FC (KOR)     190     83
# 29             LECKIE                  Hertha BSC (GER)     181     84
# ..                ...                               ...     ...    ...
# 706      SKHIRI JORIS             Montpellier HSC (FRA)     185     69
# 707            SRARFI                    OGC Nice (FRA)     176     71
# 708           KHALIFA               Club Africain (TUN)     185     72
# 709          CHAALELI                    ES Tunis (TUN)     179     70
# 710            NAGUEZ                     Zamalek (EGY)     186     75
# 711            HASSEN              LB Chateauroux (FRA)     186     70
# 712             SLITI                   Dijon FCO (FRA)     173     65
# 713        F. MUSLERA              Galatasaray SK (TUR)     190     74
# 714      J.M. GIMENEZ             Atletico Madrid (ESP)     185     77
# 715          D. GODIN             Atletico Madrid (ESP)     185     73
# 716         G. VARELA                  CA Penarol (URU)     173     70
# 717        C. SANCHEZ                CF Monterrey (MEX)     171     74
# 718      R. BENTANCUR                 Juventus FC (ITA)     187     73
# 719      C. RODRIGUEZ                  CA Penarol (URU)     178     79
# 720         N. NANDEZ             CA Boca Juniors (ARG)     171     61
# 721         L. SUAREZ                FC Barcelona (ESP)     182     85
# 722  G. DE ARRASCAETA                 Cruzeiro EC (BRA)     172     64
# 723         C. STUANI                   Girona FC (ESP)     186     78
# 724        M. CAMPAÑA            CA Independiente (ARG)     184     79
# 725          G. SILVA            CA Independiente (ARG)     185     74
# 726       L. TORREIRA                UC Sampdoria (ITA)     168     61
# 727         M. VECINO           FC Internazionale (ITA)     189     80
# 728        M. PEREIRA                    FC Porto (POR)     173     73
# 729         D. LAXALT                   Genoa CFC (ITA)     178     66
# 730          M. GOMEZ                  Celta Vigo (ESP)     186     85
# 731         S. COATES                 Sporting CP (POR)     196     89
# 732  J. URRETAVISCAYA                CF Monterrey (MEX)     172     66
# 733         E. CAVANI      Paris Saint-Germain FC (FRA)     188     78
# 734        M. CACERES                    SS Lazio (ITA)     178     75
# 735          M. SILVA            CR Vasco da Gama (BRA)     187     82
#
#     birth date corrected  age  age_fraction        BMI
# 0             1986-02-10   32     32.397654  30.000000
# 1             1987-03-18   31     31.299753  27.000000
# 2             1992-08-31   25     25.843104  32.500000
# 3             1986-09-20   31     31.789838  24.333333
# 4             1986-01-30   32     32.427771  24.333333
# 5             1987-03-17   31     31.302491  28.333333
# 6             1988-06-29   30     30.015675  24.333333
# 7             1991-10-28   26     26.686380  38.500000
# 8             1987-12-10   30     30.568732  25.000000
# 9             1987-06-24   31     31.031438  36.000000
# 10            1988-02-14   30     30.388030  25.000000
# 11            1986-10-16   31     31.718653  28.333333
# 12            1992-12-15   25     25.552886  25.333333
# 13            1984-06-08   34     34.073253  24.333333
# 14            1993-02-15   25     25.383136  33.000000
# 15            1990-03-20   28     28.293531  27.333333
# 16            1988-02-12   30     30.393506  27.000000
# 17            1990-07-13   27     27.978672  34.500000
# 18            1988-06-02   30     30.089598  37.000000
# 19            1996-04-09   22     22.237281  25.000000
# 20            1993-11-15   24     24.635687  24.333333
# 21            1996-01-21   22     22.453575  32.500000
# 22            1981-09-28   36     36.767353  26.666667
# 23            1992-04-08   26     26.240101  27.333333
# 24            1994-04-28   24     24.186670  28.333333
# 25            1988-04-05   30     30.248397  23.666667
# 26            1979-12-06   38     38.579848  25.333333
# 27            1985-08-04   32     32.917856  26.000000
# 28            1989-12-08   28     28.572798  27.666667
# 29            1991-02-04   27     27.414663  28.000000
# ..                   ...  ...           ...        ...
# 706           1995-05-10   23     23.154480  23.000000
# 707           1997-06-25   21     21.027126  23.666667
# 708           1986-10-14   31     31.724128  24.000000
# 709           1994-02-28   24     24.348207  23.333333
# 710           1992-10-28   25     25.684306  25.000000
# 711           1995-03-05   23     23.335181  23.333333
# 712           1992-07-27   25     25.938931  32.500000
# 713           1986-06-16   32     32.052677  24.666667
# 714           1995-01-20   23     23.455649  25.666667
# 715           1986-02-16   32     32.381226  24.333333
# 716           1993-03-24   25     25.281833  35.000000
# 717           1984-12-02   33     33.588643  37.000000
# 718           1997-06-25   21     21.027126  24.333333
# 719           1985-09-30   32     32.761795  26.333333
# 720           1995-12-28   22     22.519285  30.500000
# 721           1987-01-24   31     31.444862  28.333333
# 722           1994-06-01   24     24.093582  32.000000
# 723           1986-10-12   31     31.729604  26.000000
# 724           1989-05-29   29     29.101214  26.333333
# 725           1994-03-05   24     24.334517  24.666667
# 726           1996-02-11   22     22.396079  30.500000
# 727           1991-08-24   26     26.864344  26.666667
# 728           1984-06-08   34     34.073253  36.500000
# 729           1993-02-07   25     25.405039  22.000000
# 730           1996-08-14   21     21.889567  28.333333
# 731           1990-10-07   27     27.743212  29.666667
# 732           1990-03-19   28     28.296269  33.000000
# 733           1987-02-14   31     31.387366  26.000000
# 734           1987-04-07   31     31.244995  25.000000
# 735           1983-03-25   35     35.280670  27.333333
#
# [736 rows x 13 columns]

# %%
df.describe()
# Out:
#            Height         age  age_fraction         BMI
# count  736.000000  736.000000    736.000000  736.000000
# mean   182.407609   27.472826     27.952111   27.108469
# std      6.930924    3.934750      3.916060    3.379115
# min    165.000000   19.000000     19.499374   20.000000
# 25%    178.000000   25.000000     25.278411   25.000000
# 50%    183.000000   27.000000     27.777436   26.333333
# 75%    187.000000   30.000000     30.788449   28.333333
# max    201.000000   45.000000     45.468422   39.000000

# %%
df[df['age']==45.0]
# Out:
#          Team  # Pos. FIFA Popular Name  Birth Date Shirt Name  \
# 184  b'Egypt'  1   GK   ESSAM EL HADARY  15.01.1973   ELHADARY
#
#                     Club  Height Weight birth date corrected  age  \
# 184  Al Taawoun FC (KSA)     190     90           1973-01-15   45
#
#      age_fraction   BMI
# 184     45.468422  30.0

# %%
df[df['age']==19.0]
# Out:
#              Team   # Pos.       FIFA Popular Name  Birth Date  \
# 39   b'Australia'  17   FW           ARZANI Daniel  04.01.1999
# 228    b'England'  22   DF  ALEXANDER-ARNOLD Trent  07.10.1998
# 239     b'France'  10   FW           MBAPPE Kylian  20.12.1998
# 392    b'Morocco'   2   DF           HAKIMI Achraf  04.11.1998
# 436    b'Nigeria'  23   GK           UZOHO Francis  28.10.1998
# 596    b'Senegal'  22   DF            WAGUE Moussa  04.10.1998
#
#            Shirt Name                          Club  Height Weight  \
# 39             ARZANI       Melbourne City FC (AUS)     171     73
# 228  ALEXANDER-ARNOLD            Liverpool FC (ENG)     175     70
# 239            MBAPPE  Paris Saint-Germain FC (FRA)     178     78
# 392            HAKIMI          Real Madrid CF (ESP)     179     65
# 436             UZOHO     Deportivo La Coruña (ESP)     196     91
# 596          M. WAGUE               KAS Eupen (BEL)     177     70
#
#     birth date corrected  age  age_fraction        BMI
# 39            1999-01-04   19     19.499374  36.500000
# 228           1998-10-07   19     19.743047  23.333333
# 239           1998-12-20   19     19.540442  26.000000
# 392           1998-11-04   19     19.666386  21.666667
# 436           1998-10-28   19     19.685551  30.333333
# 596           1998-10-04   19     19.751261  23.333333

# %%
df[df['BMI']==20.0]
# Out:
#            Team  # Pos. FIFA Popular Name  Birth Date Shirt Name  \
# 213  b'England'  7   MF     LINGARD Jesse  15.12.1992    LINGARD
#
#                            Club  Height Weight birth date corrected  age  \
# 213  Manchester United FC (ENG)     175     60           1992-12-15   25
#
#      age_fraction   BMI
# 213     25.552886  20.0

# %%
# club origin
def get_club_origin(x):
    return str(x['Club']).split("(")[1].split(")")[0]
 
#test
x0=dict()
x0["Club"] = "Manchester United FC (ENG)"
print(get_club_origin(x0))
# Out:
# ENG

# %%
df['Club origin']=df.apply(lambda x:get_club_origin(x),axis=1)

# %%
df.head()
# Out:
#            Team  # Pos.   FIFA Popular Name  Birth Date  Shirt Name  \
# 0  b'Argentina'  1   GK       GUZMAN Nahuel  10.02.1986      GUZMÁN
# 1  b'Argentina'  2   DF     MERCADO Gabriel  18.03.1987     MERCADO
# 2  b'Argentina'  3   DF  TAGLIAFICO Nicolas  31.08.1992  TAGLIAFICO
# 3  b'Argentina'  4   DF    ANSALDI Cristian  20.09.1986     ANSALDI
# 4  b'Argentina'  5   MF        BIGLIA Lucas  30.01.1986      BIGLIA
#
#                 Club  Height Weight birth date corrected  age  age_fraction  \
# 0  Tigres UANL (MEX)     192     90           1986-02-10   32     32.397654
# 1   Sevilla FC (ESP)     181     81           1987-03-18   31     31.299753
# 2     AFC Ajax (NED)     169     65           1992-08-31   25     25.843104
# 3    Torino FC (ITA)     181     73           1986-09-20   31     31.789838
# 4     AC Milan (ITA)     175     73           1986-01-30   32     32.427771
#
#          BMI Club origin
# 0  30.000000         MEX
# 1  27.000000         ESP
# 2  32.500000         NED
# 3  24.333333         ITA
# 4  24.333333         ITA

# %%
# get the 3letter code of team
import pycountry
print(pycountry.countries.get(name="England"))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-0b9c402ca08c> in <module>()
#       1 # get the 3letter code of team
#       2 import pycountry
# ----> 3 print(pycountry.countries.get(name="England"))
#
# ~/anaconda3/lib/python3.6/site-packages/pycountry/db.py in load_if_needed(self, *args, **kw)
#      41         if not self._is_loaded:
#      42             self._load()
# ---> 43         return f(self, *args, **kw)
#      44     return load_if_needed
#      45
#
# ~/anaconda3/lib/python3.6/site-packages/pycountry/db.py in get(self, **kw)
#      99             raise TypeError('Only one criteria may be given')
#     100         field, value = kw.popitem()
# --> 101         return self.indices[field][value]
#     102
#     103     @lazy_load
#
# KeyError: 'England'

# %%
# remove b from team
df['Team'] = df['Team'].str.decode('utf-8')

# %%
def get_3_letter_code(x):
    # special cases not handled by pycountry (why not??)
    if (str(x['Team'])=='England'):
        return "ENG"
    if (str(x['Team'])=="IR Iran"):
        return "IRN"
    if (str(x['Team'])=="Korea Republic"):
        return "KOR"
    if (str(x['Team'])=="Russia"):
        return "RUS"
    return pycountry.countries.get(name=str(x["Team"])).alpha_3

df['Country_3']=df.apply(lambda x:get_3_letter_code(x),axis=1)

# %%
for p in pycountry.countries:
    print(p)
# Out:
# Country(alpha_2='AW', alpha_3='ABW', name='Aruba', numeric='533')
# Country(alpha_2='AF', alpha_3='AFG', name='Afghanistan', numeric='004', official_name='Islamic Republic of Afghanistan')
# Country(alpha_2='AO', alpha_3='AGO', name='Angola', numeric='024', official_name='Republic of Angola')
# Country(alpha_2='AI', alpha_3='AIA', name='Anguilla', numeric='660')
# Country(alpha_2='AX', alpha_3='ALA', name='Åland Islands', numeric='248')
# Country(alpha_2='AL', alpha_3='ALB', name='Albania', numeric='008', official_name='Republic of Albania')
# Country(alpha_2='AD', alpha_3='AND', name='Andorra', numeric='020', official_name='Principality of Andorra')
# Country(alpha_2='AE', alpha_3='ARE', name='United Arab Emirates', numeric='784')
# Country(alpha_2='AR', alpha_3='ARG', name='Argentina', numeric='032', official_name='Argentine Republic')
# Country(alpha_2='AM', alpha_3='ARM', name='Armenia', numeric='051', official_name='Republic of Armenia')
# Country(alpha_2='AS', alpha_3='ASM', name='American Samoa', numeric='016')
# Country(alpha_2='AQ', alpha_3='ATA', name='Antarctica', numeric='010')
# Country(alpha_2='TF', alpha_3='ATF', name='French Southern Territories', numeric='260')
# Country(alpha_2='AG', alpha_3='ATG', name='Antigua and Barbuda', numeric='028')
# Country(alpha_2='AU', alpha_3='AUS', name='Australia', numeric='036')
# Country(alpha_2='AT', alpha_3='AUT', name='Austria', numeric='040', official_name='Republic of Austria')
# Country(alpha_2='AZ', alpha_3='AZE', name='Azerbaijan', numeric='031', official_name='Republic of Azerbaijan')
# Country(alpha_2='BI', alpha_3='BDI', name='Burundi', numeric='108', official_name='Republic of Burundi')
# Country(alpha_2='BE', alpha_3='BEL', name='Belgium', numeric='056', official_name='Kingdom of Belgium')
# Country(alpha_2='BJ', alpha_3='BEN', name='Benin', numeric='204', official_name='Republic of Benin')
# Country(alpha_2='BQ', alpha_3='BES', name='Bonaire, Sint Eustatius and Saba', numeric='535', official_name='Bonaire, Sint Eustatius and Saba')
# Country(alpha_2='BF', alpha_3='BFA', name='Burkina Faso', numeric='854')
# Country(alpha_2='BD', alpha_3='BGD', name='Bangladesh', numeric='050', official_name="People's Republic of Bangladesh")
# Country(alpha_2='BG', alpha_3='BGR', name='Bulgaria', numeric='100', official_name='Republic of Bulgaria')
# Country(alpha_2='BH', alpha_3='BHR', name='Bahrain', numeric='048', official_name='Kingdom of Bahrain')
# Country(alpha_2='BS', alpha_3='BHS', name='Bahamas', numeric='044', official_name='Commonwealth of the Bahamas')
# Country(alpha_2='BA', alpha_3='BIH', name='Bosnia and Herzegovina', numeric='070', official_name='Republic of Bosnia and Herzegovina')
# Country(alpha_2='BL', alpha_3='BLM', name='Saint Barthélemy', numeric='652')
# Country(alpha_2='BY', alpha_3='BLR', name='Belarus', numeric='112', official_name='Republic of Belarus')
# Country(alpha_2='BZ', alpha_3='BLZ', name='Belize', numeric='084')
# Country(alpha_2='BM', alpha_3='BMU', name='Bermuda', numeric='060')
# Country(alpha_2='BO', alpha_3='BOL', common_name='Bolivia', name='Bolivia, Plurinational State of', numeric='068', official_name='Plurinational State of Bolivia')
# Country(alpha_2='BR', alpha_3='BRA', name='Brazil', numeric='076', official_name='Federative Republic of Brazil')
# Country(alpha_2='BB', alpha_3='BRB', name='Barbados', numeric='052')
# Country(alpha_2='BN', alpha_3='BRN', name='Brunei Darussalam', numeric='096')
# Country(alpha_2='BT', alpha_3='BTN', name='Bhutan', numeric='064', official_name='Kingdom of Bhutan')
# Country(alpha_2='BV', alpha_3='BVT', name='Bouvet Island', numeric='074')
# Country(alpha_2='BW', alpha_3='BWA', name='Botswana', numeric='072', official_name='Republic of Botswana')
# Country(alpha_2='CF', alpha_3='CAF', name='Central African Republic', numeric='140')
# Country(alpha_2='CA', alpha_3='CAN', name='Canada', numeric='124')
# Country(alpha_2='CC', alpha_3='CCK', name='Cocos (Keeling) Islands', numeric='166')
# Country(alpha_2='CH', alpha_3='CHE', name='Switzerland', numeric='756', official_name='Swiss Confederation')
# Country(alpha_2='CL', alpha_3='CHL', name='Chile', numeric='152', official_name='Republic of Chile')
# Country(alpha_2='CN', alpha_3='CHN', name='China', numeric='156', official_name="People's Republic of China")
# Country(alpha_2='CI', alpha_3='CIV', name="Côte d'Ivoire", numeric='384', official_name="Republic of Côte d'Ivoire")
# Country(alpha_2='CM', alpha_3='CMR', name='Cameroon', numeric='120', official_name='Republic of Cameroon')
# Country(alpha_2='CD', alpha_3='COD', name='Congo, The Democratic Republic of the', numeric='180')
# Country(alpha_2='CG', alpha_3='COG', name='Congo', numeric='178', official_name='Republic of the Congo')
# Country(alpha_2='CK', alpha_3='COK', name='Cook Islands', numeric='184')
# Country(alpha_2='CO', alpha_3='COL', name='Colombia', numeric='170', official_name='Republic of Colombia')
# Country(alpha_2='KM', alpha_3='COM', name='Comoros', numeric='174', official_name='Union of the Comoros')
# Country(alpha_2='CV', alpha_3='CPV', name='Cabo Verde', numeric='132', official_name='Republic of Cabo Verde')
# Country(alpha_2='CR', alpha_3='CRI', name='Costa Rica', numeric='188', official_name='Republic of Costa Rica')
# Country(alpha_2='CU', alpha_3='CUB', name='Cuba', numeric='192', official_name='Republic of Cuba')
# Country(alpha_2='CW', alpha_3='CUW', name='Curaçao', numeric='531', official_name='Curaçao')
# Country(alpha_2='CX', alpha_3='CXR', name='Christmas Island', numeric='162')
# Country(alpha_2='KY', alpha_3='CYM', name='Cayman Islands', numeric='136')
# Country(alpha_2='CY', alpha_3='CYP', name='Cyprus', numeric='196', official_name='Republic of Cyprus')
# Country(alpha_2='CZ', alpha_3='CZE', name='Czechia', numeric='203', official_name='Czech Republic')
# Country(alpha_2='DE', alpha_3='DEU', name='Germany', numeric='276', official_name='Federal Republic of Germany')
# Country(alpha_2='DJ', alpha_3='DJI', name='Djibouti', numeric='262', official_name='Republic of Djibouti')
# Country(alpha_2='DM', alpha_3='DMA', name='Dominica', numeric='212', official_name='Commonwealth of Dominica')
# Country(alpha_2='DK', alpha_3='DNK', name='Denmark', numeric='208', official_name='Kingdom of Denmark')
# Country(alpha_2='DO', alpha_3='DOM', name='Dominican Republic', numeric='214')
# Country(alpha_2='DZ', alpha_3='DZA', name='Algeria', numeric='012', official_name="People's Democratic Republic of Algeria")
# Country(alpha_2='EC', alpha_3='ECU', name='Ecuador', numeric='218', official_name='Republic of Ecuador')
# Country(alpha_2='EG', alpha_3='EGY', name='Egypt', numeric='818', official_name='Arab Republic of Egypt')
# Country(alpha_2='ER', alpha_3='ERI', name='Eritrea', numeric='232', official_name='the State of Eritrea')
# Country(alpha_2='EH', alpha_3='ESH', name='Western Sahara', numeric='732')
# Country(alpha_2='ES', alpha_3='ESP', name='Spain', numeric='724', official_name='Kingdom of Spain')
# Country(alpha_2='EE', alpha_3='EST', name='Estonia', numeric='233', official_name='Republic of Estonia')
# Country(alpha_2='ET', alpha_3='ETH', name='Ethiopia', numeric='231', official_name='Federal Democratic Republic of Ethiopia')
# Country(alpha_2='FI', alpha_3='FIN', name='Finland', numeric='246', official_name='Republic of Finland')
# Country(alpha_2='FJ', alpha_3='FJI', name='Fiji', numeric='242', official_name='Republic of Fiji')
# Country(alpha_2='FK', alpha_3='FLK', name='Falkland Islands (Malvinas)', numeric='238')
# Country(alpha_2='FR', alpha_3='FRA', name='France', numeric='250', official_name='French Republic')
# Country(alpha_2='FO', alpha_3='FRO', name='Faroe Islands', numeric='234')
# Country(alpha_2='FM', alpha_3='FSM', name='Micronesia, Federated States of', numeric='583', official_name='Federated States of Micronesia')
# Country(alpha_2='GA', alpha_3='GAB', name='Gabon', numeric='266', official_name='Gabonese Republic')
# Country(alpha_2='GB', alpha_3='GBR', name='United Kingdom', numeric='826', official_name='United Kingdom of Great Britain and Northern Ireland')
# Country(alpha_2='GE', alpha_3='GEO', name='Georgia', numeric='268')
# Country(alpha_2='GG', alpha_3='GGY', name='Guernsey', numeric='831')
# Country(alpha_2='GH', alpha_3='GHA', name='Ghana', numeric='288', official_name='Republic of Ghana')
# Country(alpha_2='GI', alpha_3='GIB', name='Gibraltar', numeric='292')
# Country(alpha_2='GN', alpha_3='GIN', name='Guinea', numeric='324', official_name='Republic of Guinea')
# Country(alpha_2='GP', alpha_3='GLP', name='Guadeloupe', numeric='312')
# Country(alpha_2='GM', alpha_3='GMB', name='Gambia', numeric='270', official_name='Islamic Republic of the Gambia')
# Country(alpha_2='GW', alpha_3='GNB', name='Guinea-Bissau', numeric='624', official_name='Republic of Guinea-Bissau')
# Country(alpha_2='GQ', alpha_3='GNQ', name='Equatorial Guinea', numeric='226', official_name='Republic of Equatorial Guinea')
# Country(alpha_2='GR', alpha_3='GRC', name='Greece', numeric='300', official_name='Hellenic Republic')
# Country(alpha_2='GD', alpha_3='GRD', name='Grenada', numeric='308')
# Country(alpha_2='GL', alpha_3='GRL', name='Greenland', numeric='304')
# Country(alpha_2='GT', alpha_3='GTM', name='Guatemala', numeric='320', official_name='Republic of Guatemala')
# Country(alpha_2='GF', alpha_3='GUF', name='French Guiana', numeric='254')
# Country(alpha_2='GU', alpha_3='GUM', name='Guam', numeric='316')
# Country(alpha_2='GY', alpha_3='GUY', name='Guyana', numeric='328', official_name='Republic of Guyana')
# Country(alpha_2='HK', alpha_3='HKG', name='Hong Kong', numeric='344', official_name='Hong Kong Special Administrative Region of China')
# Country(alpha_2='HM', alpha_3='HMD', name='Heard Island and McDonald Islands', numeric='334')
# Country(alpha_2='HN', alpha_3='HND', name='Honduras', numeric='340', official_name='Republic of Honduras')
# Country(alpha_2='HR', alpha_3='HRV', name='Croatia', numeric='191', official_name='Republic of Croatia')
# Country(alpha_2='HT', alpha_3='HTI', name='Haiti', numeric='332', official_name='Republic of Haiti')
# Country(alpha_2='HU', alpha_3='HUN', name='Hungary', numeric='348', official_name='Hungary')
# Country(alpha_2='ID', alpha_3='IDN', name='Indonesia', numeric='360', official_name='Republic of Indonesia')
# Country(alpha_2='IM', alpha_3='IMN', name='Isle of Man', numeric='833')
# Country(alpha_2='IN', alpha_3='IND', name='India', numeric='356', official_name='Republic of India')
# Country(alpha_2='IO', alpha_3='IOT', name='British Indian Ocean Territory', numeric='086')
# Country(alpha_2='IE', alpha_3='IRL', name='Ireland', numeric='372')
# Country(alpha_2='IR', alpha_3='IRN', name='Iran, Islamic Republic of', numeric='364', official_name='Islamic Republic of Iran')
# Country(alpha_2='IQ', alpha_3='IRQ', name='Iraq', numeric='368', official_name='Republic of Iraq')
# Country(alpha_2='IS', alpha_3='ISL', name='Iceland', numeric='352', official_name='Republic of Iceland')
# Country(alpha_2='IL', alpha_3='ISR', name='Israel', numeric='376', official_name='State of Israel')
# Country(alpha_2='IT', alpha_3='ITA', name='Italy', numeric='380', official_name='Italian Republic')
# Country(alpha_2='JM', alpha_3='JAM', name='Jamaica', numeric='388')
# Country(alpha_2='JE', alpha_3='JEY', name='Jersey', numeric='832')
# Country(alpha_2='JO', alpha_3='JOR', name='Jordan', numeric='400', official_name='Hashemite Kingdom of Jordan')
# Country(alpha_2='JP', alpha_3='JPN', name='Japan', numeric='392')
# Country(alpha_2='KZ', alpha_3='KAZ', name='Kazakhstan', numeric='398', official_name='Republic of Kazakhstan')
# Country(alpha_2='KE', alpha_3='KEN', name='Kenya', numeric='404', official_name='Republic of Kenya')
# Country(alpha_2='KG', alpha_3='KGZ', name='Kyrgyzstan', numeric='417', official_name='Kyrgyz Republic')
# Country(alpha_2='KH', alpha_3='KHM', name='Cambodia', numeric='116', official_name='Kingdom of Cambodia')
# Country(alpha_2='KI', alpha_3='KIR', name='Kiribati', numeric='296', official_name='Republic of Kiribati')
# Country(alpha_2='KN', alpha_3='KNA', name='Saint Kitts and Nevis', numeric='659')
# Country(alpha_2='KR', alpha_3='KOR', name='Korea, Republic of', numeric='410')
# Country(alpha_2='KW', alpha_3='KWT', name='Kuwait', numeric='414', official_name='State of Kuwait')
# Country(alpha_2='LA', alpha_3='LAO', name="Lao People's Democratic Republic", numeric='418')
# Country(alpha_2='LB', alpha_3='LBN', name='Lebanon', numeric='422', official_name='Lebanese Republic')
# Country(alpha_2='LR', alpha_3='LBR', name='Liberia', numeric='430', official_name='Republic of Liberia')
# Country(alpha_2='LY', alpha_3='LBY', name='Libya', numeric='434', official_name='Libya')
# Country(alpha_2='LC', alpha_3='LCA', name='Saint Lucia', numeric='662')
# Country(alpha_2='LI', alpha_3='LIE', name='Liechtenstein', numeric='438', official_name='Principality of Liechtenstein')
# Country(alpha_2='LK', alpha_3='LKA', name='Sri Lanka', numeric='144', official_name='Democratic Socialist Republic of Sri Lanka')
# Country(alpha_2='LS', alpha_3='LSO', name='Lesotho', numeric='426', official_name='Kingdom of Lesotho')
# Country(alpha_2='LT', alpha_3='LTU', name='Lithuania', numeric='440', official_name='Republic of Lithuania')
# Country(alpha_2='LU', alpha_3='LUX', name='Luxembourg', numeric='442', official_name='Grand Duchy of Luxembourg')
# Country(alpha_2='LV', alpha_3='LVA', name='Latvia', numeric='428', official_name='Republic of Latvia')
# Country(alpha_2='MO', alpha_3='MAC', name='Macao', numeric='446', official_name='Macao Special Administrative Region of China')
# Country(alpha_2='MF', alpha_3='MAF', name='Saint Martin (French part)', numeric='663')
# Country(alpha_2='MA', alpha_3='MAR', name='Morocco', numeric='504', official_name='Kingdom of Morocco')
# Country(alpha_2='MC', alpha_3='MCO', name='Monaco', numeric='492', official_name='Principality of Monaco')
# Country(alpha_2='MD', alpha_3='MDA', common_name='Moldova', name='Moldova, Republic of', numeric='498', official_name='Republic of Moldova')
# Country(alpha_2='MG', alpha_3='MDG', name='Madagascar', numeric='450', official_name='Republic of Madagascar')
# Country(alpha_2='MV', alpha_3='MDV', name='Maldives', numeric='462', official_name='Republic of Maldives')
# Country(alpha_2='MX', alpha_3='MEX', name='Mexico', numeric='484', official_name='United Mexican States')
# Country(alpha_2='MH', alpha_3='MHL', name='Marshall Islands', numeric='584', official_name='Republic of the Marshall Islands')
# Country(alpha_2='MK', alpha_3='MKD', name='Macedonia, Republic of', numeric='807', official_name='The Former Yugoslav Republic of Macedonia')
# Country(alpha_2='ML', alpha_3='MLI', name='Mali', numeric='466', official_name='Republic of Mali')
# Country(alpha_2='MT', alpha_3='MLT', name='Malta', numeric='470', official_name='Republic of Malta')
# Country(alpha_2='MM', alpha_3='MMR', name='Myanmar', numeric='104', official_name='Republic of Myanmar')
# Country(alpha_2='ME', alpha_3='MNE', name='Montenegro', numeric='499', official_name='Montenegro')
# Country(alpha_2='MN', alpha_3='MNG', name='Mongolia', numeric='496')
# Country(alpha_2='MP', alpha_3='MNP', name='Northern Mariana Islands', numeric='580', official_name='Commonwealth of the Northern Mariana Islands')
# Country(alpha_2='MZ', alpha_3='MOZ', name='Mozambique', numeric='508', official_name='Republic of Mozambique')
# Country(alpha_2='MR', alpha_3='MRT', name='Mauritania', numeric='478', official_name='Islamic Republic of Mauritania')
# Country(alpha_2='MS', alpha_3='MSR', name='Montserrat', numeric='500')
# Country(alpha_2='MQ', alpha_3='MTQ', name='Martinique', numeric='474')
# Country(alpha_2='MU', alpha_3='MUS', name='Mauritius', numeric='480', official_name='Republic of Mauritius')
# Country(alpha_2='MW', alpha_3='MWI', name='Malawi', numeric='454', official_name='Republic of Malawi')
# Country(alpha_2='MY', alpha_3='MYS', name='Malaysia', numeric='458')
# Country(alpha_2='YT', alpha_3='MYT', name='Mayotte', numeric='175')
# Country(alpha_2='NA', alpha_3='NAM', name='Namibia', numeric='516', official_name='Republic of Namibia')
# Country(alpha_2='NC', alpha_3='NCL', name='New Caledonia', numeric='540')
# Country(alpha_2='NE', alpha_3='NER', name='Niger', numeric='562', official_name='Republic of the Niger')
# Country(alpha_2='NF', alpha_3='NFK', name='Norfolk Island', numeric='574')
# Country(alpha_2='NG', alpha_3='NGA', name='Nigeria', numeric='566', official_name='Federal Republic of Nigeria')
# Country(alpha_2='NI', alpha_3='NIC', name='Nicaragua', numeric='558', official_name='Republic of Nicaragua')
# Country(alpha_2='NU', alpha_3='NIU', name='Niue', numeric='570', official_name='Niue')
# Country(alpha_2='NL', alpha_3='NLD', name='Netherlands', numeric='528', official_name='Kingdom of the Netherlands')
# Country(alpha_2='NO', alpha_3='NOR', name='Norway', numeric='578', official_name='Kingdom of Norway')
# Country(alpha_2='NP', alpha_3='NPL', name='Nepal', numeric='524', official_name='Federal Democratic Republic of Nepal')
# Country(alpha_2='NR', alpha_3='NRU', name='Nauru', numeric='520', official_name='Republic of Nauru')
# Country(alpha_2='NZ', alpha_3='NZL', name='New Zealand', numeric='554')
# Country(alpha_2='OM', alpha_3='OMN', name='Oman', numeric='512', official_name='Sultanate of Oman')
# Country(alpha_2='PK', alpha_3='PAK', name='Pakistan', numeric='586', official_name='Islamic Republic of Pakistan')
# Country(alpha_2='PA', alpha_3='PAN', name='Panama', numeric='591', official_name='Republic of Panama')
# Country(alpha_2='PN', alpha_3='PCN', name='Pitcairn', numeric='612')
# Country(alpha_2='PE', alpha_3='PER', name='Peru', numeric='604', official_name='Republic of Peru')
# Country(alpha_2='PH', alpha_3='PHL', name='Philippines', numeric='608', official_name='Republic of the Philippines')
# Country(alpha_2='PW', alpha_3='PLW', name='Palau', numeric='585', official_name='Republic of Palau')
# Country(alpha_2='PG', alpha_3='PNG', name='Papua New Guinea', numeric='598', official_name='Independent State of Papua New Guinea')
# Country(alpha_2='PL', alpha_3='POL', name='Poland', numeric='616', official_name='Republic of Poland')
# Country(alpha_2='PR', alpha_3='PRI', name='Puerto Rico', numeric='630')
# Country(alpha_2='KP', alpha_3='PRK', name="Korea, Democratic People's Republic of", numeric='408', official_name="Democratic People's Republic of Korea")
# Country(alpha_2='PT', alpha_3='PRT', name='Portugal', numeric='620', official_name='Portuguese Republic')
# Country(alpha_2='PY', alpha_3='PRY', name='Paraguay', numeric='600', official_name='Republic of Paraguay')
# Country(alpha_2='PS', alpha_3='PSE', name='Palestine, State of', numeric='275', official_name='the State of Palestine')
# Country(alpha_2='PF', alpha_3='PYF', name='French Polynesia', numeric='258')
# Country(alpha_2='QA', alpha_3='QAT', name='Qatar', numeric='634', official_name='State of Qatar')
# Country(alpha_2='RE', alpha_3='REU', name='Réunion', numeric='638')
# Country(alpha_2='RO', alpha_3='ROU', name='Romania', numeric='642')
# Country(alpha_2='RU', alpha_3='RUS', name='Russian Federation', numeric='643')
# Country(alpha_2='RW', alpha_3='RWA', name='Rwanda', numeric='646', official_name='Rwandese Republic')
# Country(alpha_2='SA', alpha_3='SAU', name='Saudi Arabia', numeric='682', official_name='Kingdom of Saudi Arabia')
# Country(alpha_2='SD', alpha_3='SDN', name='Sudan', numeric='729', official_name='Republic of the Sudan')
# Country(alpha_2='SN', alpha_3='SEN', name='Senegal', numeric='686', official_name='Republic of Senegal')
# Country(alpha_2='SG', alpha_3='SGP', name='Singapore', numeric='702', official_name='Republic of Singapore')
# Country(alpha_2='GS', alpha_3='SGS', name='South Georgia and the South Sandwich Islands', numeric='239')
# Country(alpha_2='SH', alpha_3='SHN', name='Saint Helena, Ascension and Tristan da Cunha', numeric='654')
# Country(alpha_2='SJ', alpha_3='SJM', name='Svalbard and Jan Mayen', numeric='744')
# Country(alpha_2='SB', alpha_3='SLB', name='Solomon Islands', numeric='090')
# Country(alpha_2='SL', alpha_3='SLE', name='Sierra Leone', numeric='694', official_name='Republic of Sierra Leone')
# Country(alpha_2='SV', alpha_3='SLV', name='El Salvador', numeric='222', official_name='Republic of El Salvador')
# Country(alpha_2='SM', alpha_3='SMR', name='San Marino', numeric='674', official_name='Republic of San Marino')
# Country(alpha_2='SO', alpha_3='SOM', name='Somalia', numeric='706', official_name='Federal Republic of Somalia')
# Country(alpha_2='PM', alpha_3='SPM', name='Saint Pierre and Miquelon', numeric='666')
# Country(alpha_2='RS', alpha_3='SRB', name='Serbia', numeric='688', official_name='Republic of Serbia')
# Country(alpha_2='SS', alpha_3='SSD', name='South Sudan', numeric='728', official_name='Republic of South Sudan')
# Country(alpha_2='ST', alpha_3='STP', name='Sao Tome and Principe', numeric='678', official_name='Democratic Republic of Sao Tome and Principe')
# Country(alpha_2='SR', alpha_3='SUR', name='Suriname', numeric='740', official_name='Republic of Suriname')
# Country(alpha_2='SK', alpha_3='SVK', name='Slovakia', numeric='703', official_name='Slovak Republic')
# Country(alpha_2='SI', alpha_3='SVN', name='Slovenia', numeric='705', official_name='Republic of Slovenia')
# Country(alpha_2='SE', alpha_3='SWE', name='Sweden', numeric='752', official_name='Kingdom of Sweden')
# Country(alpha_2='SZ', alpha_3='SWZ', name='Swaziland', numeric='748', official_name='Kingdom of Swaziland')
# Country(alpha_2='SX', alpha_3='SXM', name='Sint Maarten (Dutch part)', numeric='534', official_name='Sint Maarten (Dutch part)')
# Country(alpha_2='SC', alpha_3='SYC', name='Seychelles', numeric='690', official_name='Republic of Seychelles')
# Country(alpha_2='SY', alpha_3='SYR', name='Syrian Arab Republic', numeric='760')
# Country(alpha_2='TC', alpha_3='TCA', name='Turks and Caicos Islands', numeric='796')
# Country(alpha_2='TD', alpha_3='TCD', name='Chad', numeric='148', official_name='Republic of Chad')
# Country(alpha_2='TG', alpha_3='TGO', name='Togo', numeric='768', official_name='Togolese Republic')
# Country(alpha_2='TH', alpha_3='THA', name='Thailand', numeric='764', official_name='Kingdom of Thailand')
# Country(alpha_2='TJ', alpha_3='TJK', name='Tajikistan', numeric='762', official_name='Republic of Tajikistan')
# Country(alpha_2='TK', alpha_3='TKL', name='Tokelau', numeric='772')
# Country(alpha_2='TM', alpha_3='TKM', name='Turkmenistan', numeric='795')
# Country(alpha_2='TL', alpha_3='TLS', name='Timor-Leste', numeric='626', official_name='Democratic Republic of Timor-Leste')
# Country(alpha_2='TO', alpha_3='TON', name='Tonga', numeric='776', official_name='Kingdom of Tonga')
# Country(alpha_2='TT', alpha_3='TTO', name='Trinidad and Tobago', numeric='780', official_name='Republic of Trinidad and Tobago')
# Country(alpha_2='TN', alpha_3='TUN', name='Tunisia', numeric='788', official_name='Republic of Tunisia')
# Country(alpha_2='TR', alpha_3='TUR', name='Turkey', numeric='792', official_name='Republic of Turkey')
# Country(alpha_2='TV', alpha_3='TUV', name='Tuvalu', numeric='798')
# Country(alpha_2='TW', alpha_3='TWN', common_name='Taiwan', name='Taiwan, Province of China', numeric='158', official_name='Taiwan, Province of China')
# Country(alpha_2='TZ', alpha_3='TZA', common_name='Tanzania', name='Tanzania, United Republic of', numeric='834', official_name='United Republic of Tanzania')
# Country(alpha_2='UG', alpha_3='UGA', name='Uganda', numeric='800', official_name='Republic of Uganda')
# Country(alpha_2='UA', alpha_3='UKR', name='Ukraine', numeric='804')
# Country(alpha_2='UM', alpha_3='UMI', name='United States Minor Outlying Islands', numeric='581')
# Country(alpha_2='UY', alpha_3='URY', name='Uruguay', numeric='858', official_name='Eastern Republic of Uruguay')
# Country(alpha_2='US', alpha_3='USA', name='United States', numeric='840', official_name='United States of America')
# Country(alpha_2='UZ', alpha_3='UZB', name='Uzbekistan', numeric='860', official_name='Republic of Uzbekistan')
# Country(alpha_2='VA', alpha_3='VAT', name='Holy See (Vatican City State)', numeric='336')
# Country(alpha_2='VC', alpha_3='VCT', name='Saint Vincent and the Grenadines', numeric='670')
# Country(alpha_2='VE', alpha_3='VEN', common_name='Venezuela', name='Venezuela, Bolivarian Republic of', numeric='862', official_name='Bolivarian Republic of Venezuela')
# Country(alpha_2='VG', alpha_3='VGB', name='Virgin Islands, British', numeric='092', official_name='British Virgin Islands')
# Country(alpha_2='VI', alpha_3='VIR', name='Virgin Islands, U.S.', numeric='850', official_name='Virgin Islands of the United States')
# Country(alpha_2='VN', alpha_3='VNM', common_name='Vietnam', name='Viet Nam', numeric='704', official_name='Socialist Republic of Viet Nam')
# Country(alpha_2='VU', alpha_3='VUT', name='Vanuatu', numeric='548', official_name='Republic of Vanuatu')
# Country(alpha_2='WF', alpha_3='WLF', name='Wallis and Futuna', numeric='876')
# Country(alpha_2='WS', alpha_3='WSM', name='Samoa', numeric='882', official_name='Independent State of Samoa')
# Country(alpha_2='YE', alpha_3='YEM', name='Yemen', numeric='887', official_name='Republic of Yemen')
# Country(alpha_2='ZA', alpha_3='ZAF', name='South Africa', numeric='710', official_name='Republic of South Africa')
# Country(alpha_2='ZM', alpha_3='ZMB', name='Zambia', numeric='894', official_name='Republic of Zambia')
# Country(alpha_2='ZW', alpha_3='ZWE', name='Zimbabwe', numeric='716', official_name='Republic of Zimbabwe')

# %%
df[df['Team']=="Russia"]
# Out:
#        Team   # Pos.   FIFA Popular Name  Birth Date     Shirt Name  \
# 529  Russia   1   GK       AKINFEEV Igor  08.04.1986       AKINFEEV
# 530  Russia   2   DF     MARIO FERNANDES  19.09.1990      FERNANDES
# 531  Russia   3   DF        KUTEPOV Ilya  29.07.1993        KUTEPOV
# 532  Russia   4   DF  IGNASHEVICH Sergey  14.07.1979    IGNASHEVICH
# 533  Russia   5   DF      SEMENOV Andrey  24.03.1989        SEMENOV
# 534  Russia   6   MF     CHERYSHEV Denis  26.12.1990      CHERYSHEV
# 535  Russia   7   MF       KUZIAEV Daler  15.01.1993        KUZIAEV
# 536  Russia   8   MF       GAZINSKY Iury  20.07.1989      GAZINSKII
# 537  Russia   9   MF        DZAGOEV Alan  17.06.1990        DZAGOEV
# 538  Russia  10   FW        SMOLOV Fedor  09.02.1990         SMOLOV
# 539  Russia  11   MF        ZOBNIN Roman  11.02.1994         ZOBNIN
# 540  Russia  12   GK        LUNEV Andrei  13.11.1991          LUNEV
# 541  Russia  13   DF    KUDRIASHOV Fedor  05.04.1987     KUDRIASHOV
# 542  Russia  14   DF     GRANAT Vladimir  22.05.1987         GRANAT
# 543  Russia  15   MF    MIRANCHUK Alexey  17.10.1995  MIRANCHUK AL.
# 544  Russia  16   MF     MIRANCHUK Anton  17.10.1995  MIRANCHUK AN.
# 545  Russia  17   MF   GOLOVIN Aleksandr  30.05.1996        GOLOVIN
# 546  Russia  18   MF        ZHIRKOV Yury  20.08.1983        ZHIRKOV
# 547  Russia  19   MF   SAMEDOV Alexander  19.07.1984        SAMEDOV
# 548  Russia  20   GK    GABULOV Vladimir  19.10.1983        GABULOV
# 549  Russia  21   MF   EROKHIN Aleksandr  13.10.1989        EROKHIN
# 550  Russia  22   FW        DZYUBA Artem  22.08.1988         DZYUBA
# 551  Russia  23   DF      SMOLNIKOV Igor  08.08.1988      SMOLNIKOV
#
#                               Club  Height Weight birth date corrected  age  \
# 529              CSKA Moscow (RUS)     185     83           1986-04-08   32
# 530              CSKA Moscow (RUS)     187     79           1990-09-19   27
# 531        FC Spartak Moscow (RUS)     190     82           1993-07-29   24
# 532              CSKA Moscow (RUS)     186     84           1979-07-14   38
# 533         FC Akhmat Grozny (RUS)     191     87           1989-03-24   29
# 534            Villarreal CF (ESP)     173     68           1990-12-26   27
# 535  FC Zenit St. Petersburg (RUS)     182     74           1993-01-15   25
# 536             FC Krasnodar (RUS)     180     75           1989-07-20   28
# 537              CSKA Moscow (RUS)     178     73           1990-06-17   28
# 538             FC Krasnodar (RUS)     185     79           1990-02-09   28
# 539        FC Spartak Moscow (RUS)     185     77           1994-02-11   24
# 540  FC Zenit St. Petersburg (RUS)     189     80           1991-11-13   26
# 541           FC Rubin Kazan (RUS)     187     78           1987-04-05   31
# 542           FC Rubin Kazan (RUS)     184     80           1987-05-22   31
# 543      FC Lokomotiv Moscow (RUS)     185     77           1995-10-17   22
# 544      FC Lokomotiv Moscow (RUS)     182     67           1995-10-17   22
# 545              CSKA Moscow (RUS)     178     70           1996-05-30   22
# 546  FC Zenit St. Petersburg (RUS)     180     76           1983-08-20   34
# 547        FC Spartak Moscow (RUS)     178     74           1984-07-19   33
# 548           Club Brugge KV (BEL)     190     81           1983-10-19   34
# 549  FC Zenit St. Petersburg (RUS)     191     79           1989-10-13   28
# 550          FC Arsenal Tula (RUS)     196     90           1988-08-22   29
# 551  FC Zenit St. Petersburg (RUS)     179     72           1988-08-08   29
#
#      age_fraction        BMI Club origin Country_3
# 529     32.241593  27.666667         RUS       RUS
# 530     27.792494  26.333333         RUS       RUS
# 531     24.934119  27.333333         RUS       RUS
# 532     38.976844  28.000000         RUS       RUS
# 533     29.281915  29.000000         RUS       RUS
# 534     27.524179  34.000000         ESP       RUS
# 535     25.468011  24.666667         RUS       RUS
# 536     28.958842  25.000000         RUS       RUS
# 537     28.049857  24.333333         RUS       RUS
# 538     28.400309  26.333333         RUS       RUS
# 539     24.394751  25.666667         RUS       RUS
# 540     26.642573  26.666667         RUS       RUS
# 541     31.250471  26.000000         RUS       RUS
# 542     31.121789  26.666667         RUS       RUS
# 543     22.716414  25.666667         RUS       RUS
# 544     22.716414  22.333333         RUS       RUS
# 545     22.097647  23.333333         RUS       RUS
# 546     34.875459  25.333333         RUS       RUS
# 547     33.960999  24.666667         RUS       RUS
# 548     34.711185  27.000000         BEL       RUS
# 549     28.726120  26.333333         RUS       RUS
# 550     29.867828  30.000000         RUS       RUS
# 551     29.906158  24.000000         RUS       RUS

# %%
def plays_in_home_country(x):
    return (x['Club origin']==x['Country_3'])
df['Plays_in_home_country']=df.apply(lambda x:plays_in_home_country(x),axis=1)

# %%
df_same_country =df[df['Plays_in_home_country']==True].groupby('Team',as_index=False).agg({'Plays_in_home_country':'count'})
# df.groupby('Team', as_index=False).agg({'Height':['mean','median','std']}).sort_values([("Height","mean")])

# %%
df_same_country
# Out:
#               Team  Plays_in_home_country
# 0        Argentina                      3
# 1        Australia                      3
# 2          Belgium                      1
# 3           Brazil                      3
# 4         Colombia                      3
# 5            Egypt                      8
# 6          England                     23
# 7           France                      9
# 8          IR Iran                      9
# 9          Iceland                      1
# 10           Japan                      8
# 11  Korea Republic                     12
# 12          Mexico                      8
# 13         Morocco                      2
# 14         Nigeria                      1
# 15          Panama                      3
# 16            Peru                      5
# 17          Poland                      4
# 18          Russia                     21
# 19          Serbia                      3
# 20           Spain                     17
# 21         Tunisia                      6

# %%
df[df['Plays_in_home_country']==True]
# Out:
#           Team   # Pos.   FIFA Popular Name  Birth Date     Shirt Name  \
# 11   Argentina  12   GK       ARMANI Franco  16.10.1986         ARMANI
# 12   Argentina  13   MF    MEZA Maximiliano  15.12.1992           MEZA
# 21   Argentina  22   MF      PAVON Cristian  21.01.1996          PAVÓN
# 39   Australia  17   FW       ARZANI Daniel  04.01.1999         ARZANI
# 41   Australia  19   DF       RISDON Joshua  27.07.1992         RISDON
# 43   Australia  21   FW  PETRATOS Dimitrios  10.11.1992       PETRATOS
# 68     Belgium  23   DF  DENDONCKER Leander  15.04.1995     DENDONCKER
# 72      Brazil   4   DF       PEDRO GEROMEL  21.09.1985        GEROMEL
# 84      Brazil  16   GK              CASSIO  06.06.1987         CASSIO
# 90      Brazil  22   DF              FAGNER  11.06.1989         FAGNER
# 99    Colombia   8   MF        AGUILAR Abel  06.01.1985     AGUILAR T.
# 103   Colombia  12   GK       VARGAS Camilo  09.03.1989      C. VARGAS
# 113   Colombia  22   GK       CUADRADO Jose  01.06.1985  J.F. CUADRADO
# 190      Egypt   7   DF         AHMED FATHI  10.11.1984       A. FATHI
# 191      Egypt   8   MF         TAREK HAMED  24.10.1988    TAREK HAMED
# 192      Egypt   9   FW       MARWAN MOHSEN  26.02.1989         MARWAN
# 195      Egypt  12   DF        AYMAN ASHRAF  09.04.1991      A. ASHRAF
# 198      Egypt  15   DF       MAHMOUD HAMDY  01.06.1995       M. HAMDY
# 199      Egypt  16   GK       SHERIF EKRAMY  10.07.1983         EKRAMY
# 203      Egypt  20   DF          SAMIR SAAD  01.04.1989       S. SAMIR
# 206      Egypt  23   GK   MOHAMED ELSHENAWY  18.12.1988   M. ELSHENAWY
# 207    England   1   GK     PICKFORD Jordan  07.03.1994       PICKFORD
# 208    England   2   DF         WALKER Kyle  28.05.1990         WALKER
# 209    England   3   DF          ROSE Danny  02.07.1990           ROSE
# 210    England   4   MF           DIER Eric  15.01.1994           DIER
# 211    England   5   DF         STONES John  28.05.1994         STONES
# 212    England   6   DF       MAGUIRE Harry  05.03.1993        MAGUIRE
# 213    England   7   MF       LINGARD Jesse  15.12.1992        LINGARD
# 214    England   8   MF    HENDERSON Jordan  17.06.1990      HENDERSON
# 215    England   9   FW          KANE Harry  28.07.1993           KANE
# ..         ...  ..  ...                 ...         ...            ...
# 547     Russia  19   MF   SAMEDOV Alexander  19.07.1984        SAMEDOV
# 549     Russia  21   MF   EROKHIN Aleksandr  13.10.1989        EROKHIN
# 550     Russia  22   FW        DZYUBA Artem  22.08.1988         DZYUBA
# 551     Russia  23   DF      SMOLNIKOV Igor  08.08.1988      SMOLNIKOV
# 598     Serbia   1   GK  STOJKOVIC Vladimir  28.07.1983      STOJKOVIĆ
# 611     Serbia  14   DF         RODIC Milan  02.04.1991          RODIĆ
# 615     Serbia  18   FW    RADONJIC Nemanja  15.02.1996       RADONJIĆ
# 622      Spain   2   DF       CARVAJAL Dani  11.01.1992       CARVAJAL
# 623      Spain   3   DF        PIQUE Gerard  02.02.1987          PIQUÉ
# 624      Spain   4   DF               NACHO  18.01.1990          NACHO
# 625      Spain   5   MF     BUSQUETS Sergio  16.07.1988         SERGIO
# 626      Spain   6   MF      INIESTA Andres  11.05.1984     A. INIESTA
# 627      Spain   7   MF                SAUL  21.11.1994           SAÚL
# 628      Spain   8   MF                KOKE  08.01.1992           KOKE
# 629      Spain   9   FW             RODRIGO  06.03.1991     RODRIGO M.
# 631      Spain  11   FW       VAZQUEZ Lucas  01.07.1991       LUCAS V.
# 632      Spain  12   DF    ODRIOZOLA Alvaro  14.12.1995      ODRIOZOLA
# 633      Spain  13   GK   ARRIZABALAGA Kepa  03.10.1994   ARRIZABALAGA
# 635      Spain  15   DF        RAMOS Sergio  30.03.1986          RAMOS
# 637      Spain  17   FW          ASPAS Iago  01.08.1987     IAGO ASPAS
# 638      Spain  18   DF          ALBA Jordi  21.03.1989     JORDI ALBA
# 639      Spain  19   FW         COSTA Diego  07.10.1988    DIEGO COSTA
# 640      Spain  20   MF       ASENSIO Marco  21.01.1996        ASENSIO
# 642      Spain  22   MF                ISCO  21.04.1992           ISCO
# 693    Tunisia   4   DF      MERIAH Yassine  02.07.1993         MERIAH
# 695    Tunisia   6   DF         BEDOUI Rami  19.01.1990         BEDOUI
# 698    Tunisia   9   MF         BADRI Anice  18.09.1990          BADRI
# 704    Tunisia  15   FW        KHALIL Ahmed  21.12.1994         KHALIL
# 708    Tunisia  19   FW       KHALIFA Saber  14.10.1986        KHALIFA
# 709    Tunisia  20   FW    CHAALELI Ghaylen  28.02.1994       CHAALELI
#
#                                Club  Height Weight birth date corrected  age  \
# 11             CA River Plate (ARG)     189     85           1986-10-16   31
# 12           CA Independiente (ARG)     180     76           1992-12-15   25
# 21            CA Boca Juniors (ARG)     169     65           1996-01-21   22
# 39          Melbourne City FC (AUS)     171     73           1999-01-04   19
# 41            WS Wanderers FC (AUS)     169     70           1992-07-27   25
# 43   Newcastle United Jets FC (AUS)     176     72           1992-11-10   25
# 68             RSC Anderlecht (BEL)     188     76           1995-04-15   23
# 72                Grêmio FBPA (BRA)     190     84           1985-09-21   32
# 84             SC Corinthians (BRA)     195     92           1987-06-06   31
# 90             SC Corinthians (BRA)     168     67           1989-06-11   29
# 99          AC Deportivo Cali (COL)     185     82           1985-01-06   33
# 103         AC Deportivo Cali (COL)     185     80           1989-03-09   29
# 113            CD Once Caldas (COL)     180     80           1985-06-01   33
# 190                Al Ahly SC (EGY)     176     76           1984-11-10   33
# 191                   Zamalek (EGY)     169     67           1988-10-24   29
# 192                Al Ahly SC (EGY)     185     81           1989-02-26   29
# 195                Al Ahly SC (EGY)     176     73           1991-04-09   27
# 198                   Zamalek (EGY)     173     72           1995-06-01   23
# 199                Al Ahly SC (EGY)     193     93           1983-07-10   34
# 203                Al Ahly SC (EGY)     183     82           1989-04-01   29
# 206                Al Ahly SC (EGY)     191     86           1988-12-18   29
# 207                Everton FC (ENG)     185     72           1994-03-07   24
# 208        Manchester City FC (ENG)     178     83           1990-05-28   28
# 209      Tottenham Hotspur FC (ENG)     173     76           1990-07-02   28
# 210      Tottenham Hotspur FC (ENG)     188     90           1994-01-15   24
# 211        Manchester City FC (ENG)     188     72           1994-05-28   24
# 212         Leicester City FC (ENG)     193     98           1993-03-05   25
# 213      Manchester United FC (ENG)     175     60           1992-12-15   25
# 214              Liverpool FC (ENG)     183     82           1990-06-17   28
# 215      Tottenham Hotspur FC (ENG)     188     98           1993-07-28   24
# ..                              ...     ...    ...                  ...  ...
# 547         FC Spartak Moscow (RUS)     178     74           1984-07-19   33
# 549   FC Zenit St. Petersburg (RUS)     191     79           1989-10-13   28
# 550           FC Arsenal Tula (RUS)     196     90           1988-08-22   29
# 551   FC Zenit St. Petersburg (RUS)     179     72           1988-08-08   29
# 598               FK Partizan (SRB)     195     92           1983-07-28   34
# 611          FK Crvena Zvezda (SRB)     185     69           1991-04-02   27
# 615          FK Crvena Zvezda (SRB)     185     76           1996-02-15   22
# 622            Real Madrid CF (ESP)     173     73           1992-01-11   26
# 623              FC Barcelona (ESP)     194     85           1987-02-02   31
# 624            Real Madrid CF (ESP)     179     77           1990-01-18   28
# 625              FC Barcelona (ESP)     189     78           1988-07-16   29
# 626              FC Barcelona (ESP)     171     68           1984-05-11   34
# 627           Atletico Madrid (ESP)     183     76           1994-11-21   23
# 628           Atletico Madrid (ESP)     176     73           1992-01-08   26
# 629               Valencia CF (ESP)     182     72           1991-03-06   27
# 631            Real Madrid CF (ESP)     173     70           1991-07-01   27
# 632             Real Sociedad (ESP)     178     67           1995-12-14   22
# 633           Athletic Bilbao (ESP)     189     84           1994-10-03   23
# 635            Real Madrid CF (ESP)     183     75           1986-03-30   32
# 637                Celta Vigo (ESP)     176     67           1987-08-01   30
# 638              FC Barcelona (ESP)     170     68           1989-03-21   29
# 639           Atletico Madrid (ESP)     185     86           1988-10-07   29
# 640            Real Madrid CF (ESP)     182     76           1996-01-21   22
# 642            Real Madrid CF (ESP)     176     74           1992-04-21   26
# 693                CS Sfaxien (TUN)     183     70           1993-07-02   25
# 695           Étoile du Sahel (TUN)     187     77           1990-01-19   28
# 698                  ES Tunis (TUN)     178     70           1990-09-18   27
# 704             Club Africain (TUN)     187     75           1994-12-21   23
# 708             Club Africain (TUN)     185     72           1986-10-14   31
# 709                  ES Tunis (TUN)     179     70           1994-02-28   24
#
#      age_fraction        BMI Club origin Country_3  Plays_in_home_country
# 11      31.718653  28.333333         ARG       ARG                   True
# 12      25.552886  25.333333         ARG       ARG                   True
# 21      22.453575  32.500000         ARG       ARG                   True
# 39      19.499374  36.500000         AUS       AUS                   True
# 41      25.938931  35.000000         AUS       AUS                   True
# 43      25.648713  24.000000         AUS       AUS                   True
# 68      23.222927  25.333333         BEL       BEL                   True
# 72      32.786436  28.000000         BRA       BRA                   True
# 84      31.080720  30.666667         BRA       BRA                   True
# 90      29.065621  33.500000         BRA       BRA                   True
# 99      33.492816  27.333333         COL       COL                   True
# 103     29.322984  26.666667         COL       COL                   True
# 113     33.093082  26.666667         COL       COL                   True
# 190     33.648877  25.333333         EGY       EGY                   True
# 191     29.695339  33.500000         EGY       EGY                   True
# 192     29.353101  27.000000         EGY       EGY                   True
# 195     27.239437  24.333333         EGY       EGY                   True
# 198     23.094246  36.000000         EGY       EGY                   True
# 199     34.987714  31.000000         EGY       EGY                   True
# 203     29.260012  27.333333         EGY       EGY                   True
# 206     29.544755  28.666667         EGY       EGY                   True
# 207     24.329042  24.000000         ENG       ENG                   True
# 208     28.104615  27.666667         ENG       ENG                   True
# 209     28.008789  38.000000         ENG       ENG                   True
# 210     24.468675  30.000000         ENG       ENG                   True
# 211     24.104533  24.000000         ENG       ENG                   True
# 212     25.333854  32.666667         ENG       ENG                   True
# 213     25.552886  20.000000         ENG       ENG                   True
# 214     28.049857  27.333333         ENG       ENG                   True
# 215     24.936857  32.666667         ENG       ENG                   True
# ..            ...        ...         ...       ...                    ...
# 547     33.960999  24.666667         RUS       RUS                   True
# 549     28.726120  26.333333         RUS       RUS                   True
# 550     29.867828  30.000000         RUS       RUS                   True
# 551     29.906158  24.000000         RUS       RUS                   True
# 598     34.938431  30.666667         SRB       SRB                   True
# 611     27.258602  23.000000         SRB       SRB                   True
# 615     22.385128  25.333333         SRB       SRB                   True
# 622     26.481037  36.500000         ESP       ESP                   True
# 623     31.420221  28.333333         ESP       ESP                   True
# 624     28.460543  25.666667         ESP       ESP                   True
# 625     29.969130  26.000000         ESP       ESP                   True
# 626     34.149914  34.000000         ESP       ESP                   True
# 627     23.619924  25.333333         ESP       ESP                   True
# 628     26.489250  24.333333         ESP       ESP                   True
# 629     27.332526  24.000000         ESP       ESP                   True
# 631     27.012191  35.000000         ESP       ESP                   True
# 632     22.557616  22.333333         ESP       ESP                   True
# 633     23.754081  28.000000         ESP       ESP                   True
# 635     32.266234  25.000000         ESP       ESP                   True
# 637     30.927398  22.333333         ESP       ESP                   True
# 638     29.290129  34.000000         ESP       ESP                   True
# 639     29.741884  28.666667         ESP       ESP                   True
# 640     22.453575  25.333333         ESP       ESP                   True
# 642     26.204508  24.666667         ESP       ESP                   True
# 693     25.008043  23.333333         TUN       TUN                   True
# 695     28.457805  25.666667         TUN       TUN                   True
# 698     27.795232  23.333333         TUN       TUN                   True
# 704     23.537787  25.000000         TUN       TUN                   True
# 708     31.724128  24.000000         TUN       TUN                   True
# 709     24.348207  23.333333         TUN       TUN                   True
#
# [153 rows x 16 columns]

# %%
df_clubs_origin = df.groupby("Club origin",as_index=False).agg({"Plays_in_home_country":"count"})
df_clubs_origin
# Out:
#    Club origin  Plays_in_home_country
# 0          ARG                      9
# 1          AUS                      3
# 2          AUT                      2
# 3          BEL                     16
# 4          BRA                      9
# 5          BUL                      2
# 6          CAN                      1
# 7          CHI                      2
# 8          CHN                      8
# 9          COL                      6
# 10         CRC                      7
# 11         CRO                      3
# 12         DEN                      8
# 13         EGY                     10
# 14         ENG                    124
# 15         ESP                     81
# 16         FIN                      1
# 17         FRA                     49
# 18         GER                     67
# 19         GRE                      5
# 20         GUA                      2
# 21         GUI                      1
# 22         HON                      1
# 23         IRN                      9
# 24         ISL                      1
# 25         ISR                      2
# 26         ITA                     58
# 27         JPN                     15
# 28         KOR                     13
# 29         KSA                     30
# 30         MAR                      2
# 31         MEX                     22
# 32         NED                     15
# 33         NGA                      1
# 34         NOR                      1
# 35         PAN                      3
# 36         PER                      7
# 37         POL                      4
# 38         POR                     19
# 39         QAT                      2
# 40         ROU                      1
# 41         RSA                      1
# 42         RUS                     36
# 43         SCO                      7
# 44         SRB                      3
# 45         SUI                      4
# 46         SVK                      1
# 47         SWE                      3
# 48         TUN                      6
# 49         TUR                     22
# 50         UAE                      2
# 51         UKR                      3
# 52         URU                      2
# 53         USA                     18
# 54         WAL                      6

# %%
df_clubs_origin_sorted =df_clubs_origin.sort_values(['Plays_in_home_country'],ascending=False)
df_clubs_origin_sorted.head(10)
# Out:
#    Club origin  Plays_in_home_country
# 14         ENG                    124
# 15         ESP                     81
# 18         GER                     67
# 26         ITA                     58
# 17         FRA                     49
# 42         RUS                     36
# 29         KSA                     30
# 31         MEX                     22
# 49         TUR                     22
# 38         POR                     19

# %%
df_clubs_origin_sorted['Club origin'][0:10]
# Out:
# 14    ENG
# 15    ESP
# 18    GER
# 26    ITA
# 17    FRA
# 42    RUS
# 29    KSA
# 31    MEX
# 49    TUR
# 38    POR
# Name: Club origin, dtype: object

# %%
ax = df_clubs_origin_sorted['Plays_in_home_country'][0:10].plot(x=df_clubs_origin_sorted['Club origin'][0:10],kind="bar",color=['blue'])

# %%
df_clubs = df.groupby("Club",as_index=True).agg({'Club':['count']}).sort_values([("Club","count")],ascending=False)
# df.groupby('Team', as_index=False).agg({'Height':['mean','median','std']}).sort_values([("Height","mean")])
df_clubs
# Out:
#                                     Club
#                                    count
# Club
# Manchester City FC (ENG)              16
# Real Madrid CF (ESP)                  15
# FC Barcelona (ESP)                    14
# Paris Saint-Germain FC (FRA)          12
# Chelsea FC (ENG)                      12
# Tottenham Hotspur FC (ENG)            12
# Manchester United FC (ENG)            11
# FC Bayern München (GER)               11
# Juventus FC (ITA)                     11
# Al Ahli SC (KSA)                       9
# Al Hilal SFC (KSA)                     9
# Atletico Madrid (ESP)                  9
# Leicester City FC (ENG)                8
# AS Monaco (FRA)                        8
# Liverpool FC (ENG)                     7
# Sporting CP (POR)                      7
# Arsenal FC (ENG)                       7
# Borussia Dortmund (GER)                7
# VfL Borussia Mönchengladbach (GER)     7
# Al Ahly SC (EGY)                       7
# Eintracht Frankfurt (GER)              6
# FC Lokomotiv Moscow (RUS)              6
# FC Zenit St. Petersburg (RUS)          6
# SSC Napoli (ITA)                       6
# CSKA Moscow (RUS)                      6
# Sevilla FC (ESP)                       6
# SL Benfica (POR)                       5
# AC Milan (ITA)                         5
# Deportivo La Coruña (ESP)              5
# Feyenoord Rotterdam (NED)              5
# ...                                  ...
# Leeds United FC (ENG)                  1
# Levski Sofia (BUL)                     1
# Hebei China Fortune FC (CHN)           1
# Hannover 96 (GER)                      1
# Dinamo Bucharest (ROU)                 1
# HNK Rijeka (CRO)                       1
# EA Guingamp (FRA)                      1
# ES Troyes (FRA)                        1
# Enyimba FC (NGA)                       1
# FBC Melgar (PER)                       1
# FC Arsenal Tula (RUS)                  1
# FC Basel (SUI)                         1
# FC Dynamo Kyiv (UKR)                   1
# FC Lausanne-Sport (SUI)                1
# FC Luzern (SUI)                        1
# FC Metz (FRA)                          1
# FC Nantes (FRA)                        1
# FC Nordsjaelland (DEN)                 1
# FC Seoul (KOR)                         1
# FC St. Pauli (GER)                     1
# FC Tokyo (JPN)                         1
# FK Partizan (SRB)                      1
# Fenerbahce SK (TUR)                    1
# Fulham FC (ENG)                        1
# Gamba Osaka (JPN)                      1
# Gornik Zabrze (POL)                    1
# Goztepe SK (TUR)                       1
# Grasshopper Club (SUI)                 1
# Grêmio FBPA (BRA)                      1
# Étoile du Sahel (TUN)                  1
#
# [310 rows x 1 columns]

# %%
df['Team'].unique()
# Out:
# array(['Argentina', 'Australia', 'Belgium', 'Brazil', 'Colombia',
#        'Costa Rica', 'Croatia', 'Denmark', 'Egypt', 'England', 'France',
#        'Germany', 'Iceland', 'IR Iran', 'Japan', 'Korea Republic',
#        'Mexico', 'Morocco', 'Nigeria', 'Panama', 'Peru', 'Poland',
#        'Portugal', 'Russia', 'Saudi Arabia', 'Senegal', 'Serbia', 'Spain',
#        'Sweden', 'Switzerland', 'Tunisia', 'Uruguay'], dtype=object)

# %%
round_16_teams=['Argentina', 'Belgium', 'Brazil', 'Colombia',
       'Croatia', 'Denmark', 'England', 'France',
       'Japan', 
       'Mexico', 
       'Portugal', 'Russia', 'Spain',
       'Sweden', 'Switzerland', 'Uruguay']
len(round_16_teams)
# Out:
# 16

# %%
quarter_finals_temas = ['Belgium', 'Brazil',
       'Croatia',  'England', 'France',
        'Russia', 
       'Sweden','Uruguay']
len(quarter_finals_temas)
# Out:
# 8

# %%
df_only_R16 = df[df['Team'].isin( round_16_teams)]
df_only_R16['Team'].unique()
# Out:
# array(['Argentina', 'Belgium', 'Brazil', 'Colombia', 'Croatia', 'Denmark',
#        'England', 'France', 'Japan', 'Mexico', 'Portugal', 'Russia',
#        'Spain', 'Sweden', 'Switzerland', 'Uruguay'], dtype=object)

# %%
df_only_QF = df[df['Team'].isin(quarter_finals_temas)]
df_only_QF['Team'].unique()
# Out:
# array(['Belgium', 'Brazil', 'Croatia', 'England', 'France', 'Russia',
#        'Sweden', 'Uruguay'], dtype=object)

# %%
def visualise_top_k_represented_clubs(df, k):
    df_grouped = df.groupby("Club",as_index=True).agg({'Club':['count']}).sort_values([("Club","count")],ascending=False)
    df_grouped_top_k=df_grouped[0:k]
    ax = df_grouped_top_k['Club']['count'].plot(x=df_grouped_top_k.index,kind="bar",color=['blue'])
    
    # ax.set_xticklabels(df_age['Team'], rotation=90)
    return ax

# %%
visualise_top_k_represented_clubs(df,10)

# %%
visualise_top_k_represented_clubs(df_only_R16,10)

# %%
visualise_top_k_represented_clubs(df_only_QF,10)

# %%
fig, ax = plt.subplots()
fig.set_figheight(5)
fig.set_figwidth(15)

plt.subplot(1,3,1)
plt.ylim((0,17)) 
ax = visualise_top_k_represented_clubs(df,15)
ax = plt.gca()

plt.subplot(1,3,2)
plt.ylim((0,17))
ax2 = visualise_top_k_represented_clubs(df_only_R16,15)
ax2 = plt.gca()


plt.subplot(1,3,3)
plt.ylim((0,17))
ax3 = visualise_top_k_represented_clubs(df_only_QF,15)
ax3 = plt.gca()

# %%
"""
==================
Animated histogram
==================

This example shows how to use a path patch to draw a bunch of
rectangles for an animated histogram.

"""
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.path as path
import matplotlib.animation as animation
from IPython.display import HTML
fig, ax = plt.subplots()

# histogram our data with numpy
data = np.random.randn(1000)
n, bins = np.histogram(data, 100)

# get the corners of the rectangles for the histogram
left = np.array(bins[:-1])
right = np.array(bins[1:])
bottom = np.zeros(len(left))
top = bottom + n
nrects = len(left)

# here comes the tricky part -- we have to set up the vertex and path
# codes arrays using moveto, lineto and closepoly

# for each rect: 1 for the MOVETO, 3 for the LINETO, 1 for the
# CLOSEPOLY; the vert for the closepoly is ignored but we still need
# it to keep the codes aligned with the vertices
nverts = nrects*(1 + 3 + 1)
verts = np.zeros((nverts, 2))
codes = np.ones(nverts, int) * path.Path.LINETO
codes[0::5] = path.Path.MOVETO
codes[4::5] = path.Path.CLOSEPOLY
verts[0::5, 0] = left
verts[0::5, 1] = bottom
verts[1::5, 0] = left
verts[1::5, 1] = top
verts[2::5, 0] = right
verts[2::5, 1] = top
verts[3::5, 0] = right
verts[3::5, 1] = bottom

barpath = path.Path(verts, codes)
patch = patches.PathPatch(
    barpath, facecolor='green', edgecolor='yellow', alpha=0.5)
ax.add_patch(patch)

ax.set_xlim(left[0], right[-1])
ax.set_ylim(bottom.min(), top.max())


def animate(i):
    # simulate new data coming in
    data = np.random.randn(1000)
    n, bins = np.histogram(data, 100)
    top = bottom + n
    verts[1::5, 1] = top
    verts[2::5, 1] = top
    return [patch, ]

ani = animation.FuncAnimation(fig, animate, 1000, repeat=False, blit=True)
plt.show()
# HTML(ani.to_html5_video())
ani.save('myvideo.mp4', codec='h264')
# Out:
# /Users/lucasanastasiou/anaconda3/lib/python3.6/site-packages/matplotlib/animation.py:1218: UserWarning: MovieWriter ffmpeg unavailable
#   warnings.warn("MovieWriter %s unavailable" % writer)
